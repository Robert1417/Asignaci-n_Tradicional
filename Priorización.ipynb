# %%
import pandas as pd
import io
import json
import os
from google.oauth2.service_account import Credentials
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload

# ======================================================
# 1. Detectar entorno (Colab vs GitHub / local)
# ======================================================
def get_credentials():
    """
    - En Colab: usa MI_JSON desde userdata
    - En GitHub / local: usa variable de entorno MI_JSON
    """
    try:
        # --- Colab ---
        from google.colab import userdata
        mi_json = userdata.get("MI_JSON")
        if mi_json is None:
            raise ValueError("MI_JSON no encontrado en Colab userdata")
        info = json.loads(mi_json)
        print("Entorno detectado: Google Colab")
    except Exception:
        # --- GitHub / local ---
        mi_json = os.environ.get("MI_JSON")
        if mi_json is None:
            raise ValueError("MI_JSON no encontrado como variable de entorno")
        info = json.loads(mi_json)
        print("Entorno detectado: GitHub / local")

    return Credentials.from_service_account_info(
        info,
        scopes=[
            "https://www.googleapis.com/auth/drive.readonly",
            "https://www.googleapis.com/auth/spreadsheets.readonly",
        ],
    )

creds = get_credentials()

# ======================================================
# 2. Conexión a Google Drive API
# ======================================================
drive_service = build("drive", "v3", credentials=creds)

# ======================================================
# 3. Parámetros del archivo
# ======================================================
FILE_ID = "1NoscZ0koPUkpYk5B6S8J0NLB1AKTyjoU"
SHEET_NAME = "Diciembre 2025"

# ======================================================
# 4. Detectar tipo de archivo
# ======================================================
meta = drive_service.files().get(
    fileId=FILE_ID,
    fields="id,name,mimeType"
).execute()

mime = meta["mimeType"]
print(f"Archivo: {meta['name']}")
print(f"Tipo: {mime}")

# ======================================================
# 5. Descargar / exportar a memoria
# ======================================================
buffer = io.BytesIO()

if mime == "application/vnd.google-apps.spreadsheet":
    # Google Sheets → exportar a Excel
    request = drive_service.files().export_media(
        fileId=FILE_ID,
        mimeType="application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
    )
else:
    # Excel u otro binario
    request = drive_service.files().get_media(fileId=FILE_ID)

downloader = MediaIoBaseDownload(buffer, request)
done = False
while not done:
    _, done = downloader.next_chunk()

buffer.seek(0)

# ======================================================
# 6. Leer hoja específica con pandas
# ======================================================
df = pd.read_excel(buffer, sheet_name=SHEET_NAME)

df.head()
# Out:
# Entorno detectado: Google Colab
# Archivo: Asignaciones de Cartera Sep25-Dic25.xlsx
# Tipo: application/vnd.openxmlformats-officedocument.spreadsheetml.sheet
#    Referencia    Cedula             Nombre del cliente  Id deuda  \
# 0       44032  16539456  Harrinson Arley Cuero Tenorio    629642
# 1       48378  91490364          Alexander Gomez Duran    658347
# 2       48378  91490364          Alexander Gomez Duran    658348
# 3       49322  17658639      Robinson Rodriguez Triana    664009
# 4       51492  31173279      Janeth Jaramillo Gonzalez    680841
#
#                         correo  Deudas Activas          Banco  \
# 0  harry_12tenorio@hotmail.com               1  Banco Popular
# 1   alexgomezduran@hotmail.com               2           BBVA
# 2   alexgomezduran@hotmail.com               2     Davivienda
# 3         rotri_78@hotmail.com               1     Davivienda
# 4    jj_jara_gonzalez@live.com               2     Serfinanza
#
#    Número de Crédito  Deuda Resuelve         DBT  ...  P_Cierre    I_ESPERADO  \
# 0           6.60E+08       3834100.0   9750700.0  ...  0.056375  17832.159469
# 1          618794133       4137000.0  59682332.0  ...  0.091274  39217.510035
# 2          400107477       9716000.0  59682332.0  ...  0.042185  51213.643250
# 3  ´5917186000515781       8939539.0  15523006.0  ...  0.040268  50762.026833
# 4          636853406       3239500.0  44920100.0  ...  0.065196  29201.505528
#
#                            Negociador  Tipo Elegible P_Cierre_norm  \
# 0           Steven Mateo Aroca Garzon            NaN      0.281875
# 1           Steven Mateo Aroca Garzon            NaN      0.456369
# 2           Steven Mateo Aroca Garzon            NaN      0.295298
# 3    Wendy Vanessa Castillo Velasquez            NaN      0.281875
# 4  Sharon Natalia Hernandez Dominguez            NaN      0.456369
#
#   Días Atraso liquidacion  Estado PL Ultima Liquidacion  \
# 0                   758.0   Atrasado         2022-09-16
# 1                  1257.0   Atrasado         2021-11-26
# 2                   280.0   Atrasado         2021-11-26
# 3                     NaN     Al día         2021-10-25
# 4                     NaN     Al día         2022-08-16
#
#    dias_desde_ultima_liq  Priority_level
# 0                 1176.0     Prioridad 1
# 1                 1470.0     Prioridad 1
# 2                 1470.0     Prioridad 1
# 3                 1502.0     Prioridad 1
# 4                 1207.0     Prioridad 1
#
# [5 rows x 59 columns]

# %%
import pandas as pd
import json
import os
import gspread
from gspread_dataframe import get_as_dataframe

# ======================================================
# 1) Detectar entorno + cargar MI_JSON (Colab o GitHub/local)
# ======================================================
def cargar_creds_dict():
    # Intentar Colab
    try:
        from google.colab import userdata
        mi_json = userdata.get("MI_JSON")
        if mi_json:
            print("Entorno detectado: Google Colab")
            return json.loads(mi_json)
    except Exception:
        pass

    # GitHub/local
    mi_json = os.environ.get("MI_JSON")
    if not mi_json:
        raise ValueError("No encontré MI_JSON ni en Colab userdata ni como variable de entorno.")
    print("Entorno detectado: GitHub / local")
    return json.loads(mi_json)

creds_dict = cargar_creds_dict()

# ======================================================
# 2) Cliente gspread con Service Account (sirve en ambos entornos)
# ======================================================
gc = gspread.service_account_from_dict(creds_dict)

# ======================================================
# 3) Abrir Google Sheet + seleccionar hoja por gid
# ======================================================
url = "https://docs.google.com/spreadsheets/d/1PogjYq2cMoDpy8gJ5I3-puLvAs0y5788Qv81KSx85Ms/edit#gid=768376152"
gid = 768376152

sh = gc.open_by_url(url)
worksheet = sh.get_worksheet_by_id(gid)

# ======================================================
# 4) Convertir a DataFrame
# ======================================================
df_posibles = get_as_dataframe(worksheet, evaluate_formulas=True)

# Limpieza típica: quitar filas completamente vacías
df_posibles = df_posibles.dropna(how="all")

df_posibles.head()
# Out:
# Entorno detectado: Google Colab
#    referencia                 Nombre completo    Id deuda  Tipo de Cobro   \
# 0  42093180.0  Claudia Patricia Gonzalez Tobon  1838351.0         Pricing
# 1  42093180.0  Claudia Patricia Gonzalez Tobon  1838357.0         Pricing
# 2  42093180.0  Claudia Patricia Gonzalez Tobon  1838350.0         Pricing
# 3  42093180.0  Claudia Patricia Gonzalez Tobon  1838353.0         Pricing
# 4  52098105.0    Sandra Patricia Prieto Leiton  1875944.0         Pricing
#
#   Vehiculo de ahorro  Comisión Mensual  Apartado mensual Tipo de liquidación  \
# 0            skandia          837099.0         2950620.0         Tradicional
# 1            skandia          837099.0         2950620.0         Tradicional
# 2            skandia          837099.0         2950620.0         Tradicional
# 3            skandia          837099.0         2950620.0         Tradicional
# 4            skandia          322524.0         1206918.0         Tradicional
#
#    Potencial   Deudas activas  ...         Saldo  Apartado neto disponible  \
# 0         2.0             7.0  ... -1.115366e+07                 2113521.0
# 1        14.0             7.0  ...  1.478846e+07                 2113521.0
# 2         0.0             7.0  ... -1.448477e+07                 2113521.0
# 3         3.0             7.0  ... -9.435100e+06                 2113521.0
# 4         1.0             4.0  ... -2.448630e+06                  884394.0
#
#    Depósitos para 30%  Apartados necesarios Pago Total  Ahorro / Deuda  \
# 0            1.967225                        -5.068603        2.314700
# 1            3.629818                         6.720381        0.317161
# 2            4.301426                         5.253641        0.432665
# 3            3.529000                         4.671092        0.425483
# 4            0.323873                        -2.664156        2.307298
#
#    Status Credito/Estr     Liquidado                 Negociador  \
# 0                  0.0  Sin Liquidar  Alba Yohana Moreno Martin
# 1                  0.0  Sin Liquidar  Alba Yohana Moreno Martin
# 2                  0.0  Sin Liquidar  Alba Yohana Moreno Martin
# 3                  0.0  Sin Liquidar  Alba Yohana Moreno Martin
# 4                  0.0  Sin Liquidar  Alba Yohana Moreno Martin
#
#                               Lider  Apartados PaB
# 0  Natalia Valentina Castro Jimenez      -5.366553
# 1  Natalia Valentina Castro Jimenez       3.947892
# 2  Natalia Valentina Castro Jimenez       3.893334
# 3  Natalia Valentina Castro Jimenez       3.039533
# 4  Natalia Valentina Castro Jimenez      -2.851275
#
# [5 rows x 30 columns]

# %%
df_posibles['referencia'] = df_posibles['referencia'].astype('Int64').astype(str)
df['Referencia'] = df['Referencia'].astype('Int64').astype(str)

# %%
referencias_validas = set(df_posibles['referencia'])

df_filtrado = df[df['Referencia'].isin(referencias_validas)]

# %%
df_final = df_filtrado[
    (df_filtrado["Priority_level"] == "Prioridad 1") |
    ((df_filtrado["Priority_level"] == "Prioridad 2") &
     (df_filtrado["Estructurable"] == 1))
]

# %%
import json
import gspread
from google.oauth2.service_account import Credentials

# --- Cargar MI_JSON (Colab / GitHub) ---
try:
    from google.colab import userdata
    mi_json = userdata.get("MI_JSON")
except ImportError:
    import os
    mi_json = os.environ.get("MI_JSON")

creds_dict = json.loads(mi_json)
scopes = ["https://www.googleapis.com/auth/spreadsheets.readonly"]
creds = Credentials.from_service_account_info(creds_dict, scopes=scopes)
gc = gspread.authorize(creds)

SPREADSHEET_ID = "1O8OHuVhgwhLw8XYEBf1uBzLYrxQ45rPiZecHOnAa1Go"
GID = 1739799528

sh = gc.open_by_key(SPREADSHEET_ID)
ws = sh.get_worksheet_by_id(GID)

print("✅ Spreadsheet:", sh.title)
print("✅ Worksheet title:", ws.title)
print("✅ Rows:", ws.row_count, "| Cols:", ws.col_count)
# Out:
# ✅ Spreadsheet: Actualizaciones
# ✅ Worksheet title: act 2025
# ✅ Rows: 280703 | Cols: 7

# %%
import json
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials

# =====================================
# 1. Cargar MI_JSON (Colab / GitHub)
# =====================================
try:
    from google.colab import userdata
    mi_json = userdata.get("MI_JSON")
except ImportError:
    import os
    mi_json = os.environ.get("MI_JSON")

if mi_json is None:
    raise ValueError("MI_JSON no encontrado")

creds_dict = json.loads(mi_json)

scopes = ["https://www.googleapis.com/auth/spreadsheets.readonly"]
creds = Credentials.from_service_account_info(creds_dict, scopes=scopes)

gc = gspread.authorize(creds)

# =====================================
# 2. Abrir Sheet
# =====================================
SPREADSHEET_ID = "1O8OHuVhgwhLw8XYEBf1uBzLYrxQ45rPiZecHOnAa1Go"
GID = 1739799528

sh = gc.open_by_key(SPREADSHEET_ID)
ws = sh.get_worksheet_by_id(GID)

df_12098 = pd.DataFrame(ws.get_all_records())

print(df_12098.head())
print(df_12098.shape)
# Out:
#   expiration                                       observations  \
# 0             Stefy 8086 // 7:22 // Se valida en chat de tuy...
# 1             7:22 a. m. 02/01/2025 VivianR//8522// Crédito ...
# 2             YesseniaJ|8045|02-01-2025|9:07am|llamo a tt pa...
# 3             Actividad para Nicolle Stefy 8086 // 10:52 // ...
# 4             7:22 a. m. 02/01/2025 VivianR//8522// Crédito ...
#
#                                end  debt_id   payment_to_bank  \
# 0     stefany.rojas@gobravo.com.co  1508614   (551000000,COP)
# 1  vivian.rodriguez@gobravo.com.co  1186799   (500000000,COP)
# 2      rosa.jimenez@gobravo.com.co  1305562    (54700000,COP)
# 3     stefany.rojas@gobravo.com.co   873948  (2600000000,COP)
# 4  vivian.rodriguez@gobravo.com.co  1450752   (573800000,COP)
#
#            inserted_at  bank_reference
# 0  2025-01-02 12:23:03        51911010
# 1  2025-01-02 12:48:27      3108379218
# 2  2025-01-02 14:08:00      3103940951
# 3  2025-01-02 15:58:43      3158318257
# 4  2025-01-02 12:44:39      3022621202
# (280702, 7)

# %%
df_12098
# Out:
#        expiration                                       observations  \
# 0                  Stefy 8086 // 7:22 // Se valida en chat de tuy...
# 1                  7:22 a. m. 02/01/2025 VivianR//8522// Crédito ...
# 2                  YesseniaJ|8045|02-01-2025|9:07am|llamo a tt pa...
# 3                  Actividad para Nicolle Stefy 8086 // 10:52 // ...
# 4                  7:22 a. m. 02/01/2025 VivianR//8522// Crédito ...
# ...           ...                                                ...
# 280697             Jana||6:00 p. m. 16/12/2025 se recibe acuerdo ...
# 280698             6:13 p. m. 16/12/2025 VivianR// Adjunto acuerd...
# 280699             Jana || 5:06 p. m. 16/12/2025 lina salaz  #625...
# 280700             \nYoha/6:17pm //se valida en chat systemgroup ...
# 280701             \nYoha/6:17pm //se valida en chat systemgroup ...
#
#                                     end  debt_id   payment_to_bank  \
# 0          stefany.rojas@gobravo.com.co  1508614   (551000000,COP)
# 1       vivian.rodriguez@gobravo.com.co  1186799   (500000000,COP)
# 2           rosa.jimenez@gobravo.com.co  1305562    (54700000,COP)
# 3          stefany.rojas@gobravo.com.co   873948  (2600000000,COP)
# 4       vivian.rodriguez@gobravo.com.co  1450752   (573800000,COP)
# ...                                 ...      ...               ...
# 280697        jana.lopez@gobravo.com.co  1668586   (266057900,COP)
# 280698  vivian.rodriguez@gobravo.com.co  1331497    (58000000,COP)
# 280699        jana.lopez@gobravo.com.co  1829745   (574461400,COP)
# 280700     yohana.moreno@gobravo.com.co  1756285   (300000000,COP)
# 280701     yohana.moreno@gobravo.com.co  1756284    (80000000,COP)
#
#                 inserted_at  bank_reference
# 0       2025-01-02 12:23:03        51911010
# 1       2025-01-02 12:48:27      3108379218
# 2       2025-01-02 14:08:00      3103940951
# 3       2025-01-02 15:58:43      3158318257
# 4       2025-01-02 12:44:39      3022621202
# ...                     ...             ...
# 280697  2025-12-16 23:04:02      3157251856
# 280698  2025-12-16 23:14:01      3103849795
# 280699  2025-12-16 23:18:45      3161052468
# 280700  2025-12-16 23:19:24      1130625305
# 280701  2025-12-16 23:20:10      1130625305
#
# [280702 rows x 7 columns]

# %%
df_12098["payment_to_bank_num"] = (
    df_12098["payment_to_bank"]
    .astype(str)
    .str.extract(r"\((\d+),")   # extrae solo el número antes de la coma
    .astype("Int64")            # lo convierte a número entero (permite NaN)
)

# %%
# 1. Asegurar que las llaves tengan el mismo tipo
df_posibles["Id deuda"] = df_posibles["Id deuda"].astype("Int64")
df_final["Id deuda"]    = df_final["Id deuda"].astype("Int64")

# 2. Merge SIN alterar la cantidad de filas de df_final
df_final = df_final.merge(
    df_posibles[
        [
            "Id deuda",
            "Apartado neto disponible",
            "Depósitos para 30%",
            "Apartados necesarios Pago Total",
            "Ahorro / Deuda",
            "Comisión total",
        ]
    ],
    how="left",   # mantiene filas de df_final
    on="Id deuda"
)

# 3. Verificar que el número de filas siga siendo el mismo
print("Filas originales:", df_final.shape[0])  # después del merge debe ser igual
df_final.head()
# Out:
# Filas originales: 5046
# /tmp/ipython-input-540771249.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Id deuda"]    = df_final["Id deuda"].astype("Int64")
#   Referencia   Cedula         Nombre del cliente  Id deuda  \
# 0    5829693  5829693  Rudi Andres lasso Giraldo   1862220
# 1    5829693  5829693  Rudi Andres lasso Giraldo   1862217
# 2    5829693  5829693  Rudi Andres lasso Giraldo   1862221
# 3    5829693  5829693  Rudi Andres lasso Giraldo   1862216
# 4    5829693  5829693  Rudi Andres lasso Giraldo   1862222
#
#                        correo  Deudas Activas            Banco  \
# 0  rudyandreslasso@hotmail.es               9  Banco de Bogota
# 1  rudyandreslasso@hotmail.es               9  Banco de Bogota
# 2  rudyandreslasso@hotmail.es               9      Colsubsidio
# 3  rudyandreslasso@hotmail.es               9  Banco de Bogota
# 4  rudyandreslasso@hotmail.es               9        Falabella
#
#   Número de Crédito  Deuda Resuelve         DBT  ...  Días Atraso liquidacion  \
# 0         450668827       4841100.0  49700682.0  ...                      NaN
# 1         459918216       4187700.0  49700682.0  ...                    856.0
# 2         093518359       5179900.0  49700682.0  ...                   1082.0
# 3         000099902       3349500.0  49700682.0  ...                    743.0
# 4    00201704114130       5402782.0  49700682.0  ...                      0.0
#
#    Estado PL  Ultima Liquidacion  dias_desde_ultima_liq Priority_level  \
# 0     Al día                 NaT                    NaN    Prioridad 2
# 1   Atrasado                 NaT                    NaN    Prioridad 1
# 2   Atrasado                 NaT                    NaN    Prioridad 1
# 3   Atrasado                 NaT                    NaN    Prioridad 1
# 4     Al día                 NaT                    NaN    Prioridad 2
#
#   Apartado neto disponible  Depósitos para 30%  \
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
#
#   Apartados necesarios Pago Total  Ahorro / Deuda  Comisión total
# 0                             NaN             NaN             NaN
# 1                             NaN             NaN             NaN
# 2                             NaN             NaN             NaN
# 3                             NaN             NaN             NaN
# 4                             NaN             NaN             NaN
#
# [5 rows x 64 columns]

# %%
# 1. Asegurar que ambos estén como string (evita problemas de 12345 vs 12345.0)
df_final["Referencia"] = df_final["Referencia"].astype("Int64").astype(str)
df_12098["bank_reference"] = df_12098["bank_reference"].astype("Int64").astype(str)

# %%
# Convertir a datetime
df_12098["inserted_at"] = pd.to_datetime(df_12098["inserted_at"], errors="coerce")

# Dejar solo la fecha (sin hora)
df_12098["inserted_at"] = df_12098["inserted_at"].dt.date

# %%
import pandas as pd

# 1. Asegurar tipos correctos para llaves y fecha
df_12098["debt_id"] = df_12098["debt_id"].astype("Int64")

# Si aún no lo habías hecho:
df_12098["inserted_at"] = pd.to_datetime(df_12098["inserted_at"], errors="coerce")

# Si quieres quedarte solo con la fecha (sin hora):
df_12098["inserted_at"] = df_12098["inserted_at"].dt.date

df_final["Id deuda"] = df_final["Id deuda"].astype("Int64")

# 2. Quedarnos solo con la ÚLTIMA actualización por debt_id
df_12098_last = (
    df_12098
    .sort_values("inserted_at")                          # ordenar por fecha
    .drop_duplicates(subset="debt_id", keep="last")      # conservar la última por deuda
    [["debt_id", "inserted_at", "payment_to_bank_num"]]  # solo columnas necesarias
)

# 3. Renombrar columnas para el merge final
df_12098_last = df_12098_last.rename(
    columns={
        "inserted_at": "ult_act",
        "payment_to_bank_num": "Pab"
    }
)

# 4. Hacer el merge con df_final usando Id deuda
df_final = df_final.merge(
    df_12098_last,
    how="left",
    left_on="Id deuda",
    right_on="debt_id"
)

# 5. Eliminar columna auxiliar debt_id
df_final = df_final.drop(columns=["debt_id"])

# 6. Chequeo rápido
print(df_final[["Id deuda", "ult_act", "Pab"]].head())
print(df_final[["ult_act", "Pab"]].isna().mean())
# Out:
#    Id deuda     ult_act        Pab
# 0   1862220  2025-12-03  484110000
# 1   1862217  2025-12-03  418770000
# 2   1862221         NaN       <NA>
# 3   1862216  2025-12-03  334950000
# 4   1862222  2025-10-23  625500000
# ult_act    0.606619
# Pab        0.606619
# dtype: float64

# %%
df_final
# Out:
#       Referencia      Cedula              Nombre del cliente  Id deuda  \
# 0        5829693     5829693       Rudi Andres lasso Giraldo   1862220
# 1        5829693     5829693       Rudi Andres lasso Giraldo   1862217
# 2        5829693     5829693       Rudi Andres lasso Giraldo   1862221
# 3        5829693     5829693       Rudi Andres lasso Giraldo   1862216
# 4        5829693     5829693       Rudi Andres lasso Giraldo   1862222
# ...          ...         ...                             ...       ...
# 5041  3508329735  1032480298         KAREN DAYANA RUEDA PENA   2016621
# 5042  3508329735  1032480298         KAREN DAYANA RUEDA PENA   2016620
# 5043  3508980827    52417868  Norma Katerina Bernier Barliza   1897721
# 5044  3508980827    52417868  Norma Katerina Bernier Barliza   1897719
# 5045  3508980827    52417868  Norma Katerina Bernier Barliza   1897720
#
#                           correo  Deudas Activas            Banco  \
# 0     rudyandreslasso@hotmail.es               9  Banco de Bogota
# 1     rudyandreslasso@hotmail.es               9  Banco de Bogota
# 2     rudyandreslasso@hotmail.es               9      Colsubsidio
# 3     rudyandreslasso@hotmail.es               9  Banco de Bogota
# 4     rudyandreslasso@hotmail.es               9        Falabella
# ...                          ...             ...              ...
# 5041       karueda03@hotmail.com               5       Davivienda
# 5042       karueda03@hotmail.com               5          Nu Bank
# 5043       kata_1977@hotmail.com               4  Banco de Bogota
# 5044       kata_1977@hotmail.com               4       Serfinanza
# 5045       kata_1977@hotmail.com               4      Bancolombia
#
#      Número de Crédito  Deuda Resuelve         DBT  ...  Ultima Liquidacion  \
# 0            450668827       4841100.0  49700682.0  ...                 NaT
# 1            459918216       4187700.0  49700682.0  ...                 NaT
# 2            093518359       5179900.0  49700682.0  ...                 NaT
# 3            000099902       3349500.0  49700682.0  ...                 NaT
# 4       00201704114130       5402782.0  49700682.0  ...                 NaT
# ...                ...             ...         ...  ...                 ...
# 5041         459321109       8723000.0  81779500.0  ...                 NaT
# 5042         000001981       7260000.0  81779500.0  ...                 NaT
# 5043         000091552       2807700.0  16361900.0  ...                 NaT
# 5044         543280844       1458600.0  16361900.0  ...                 NaT
# 5045         530371351       2644400.0  16361900.0  ...                 NaT
#
#       dias_desde_ultima_liq  Priority_level  Apartado neto disponible  \
# 0                       NaN     Prioridad 2                       NaN
# 1                       NaN     Prioridad 1                       NaN
# 2                       NaN     Prioridad 1                       NaN
# 3                       NaN     Prioridad 1                       NaN
# 4                       NaN     Prioridad 2                       NaN
# ...                     ...             ...                       ...
# 5041                    NaN     Prioridad 2                       NaN
# 5042                    NaN     Prioridad 2                       NaN
# 5043                    NaN     Prioridad 1                       NaN
# 5044                    NaN     Prioridad 1                  225355.0
# 5045                    NaN     Prioridad 2                       NaN
#
#      Depósitos para 30% Apartados necesarios Pago Total  Ahorro / Deuda  \
# 0                   NaN                             NaN             NaN
# 1                   NaN                             NaN             NaN
# 2                   NaN                             NaN             NaN
# 3                   NaN                             NaN             NaN
# 4                   NaN                             NaN             NaN
# ...                 ...                             ...             ...
# 5041                NaN                             NaN             NaN
# 5042                NaN                             NaN             NaN
# 5043                NaN                             NaN             NaN
# 5044           5.963249                         6.09483             0.0
# 5045                NaN                             NaN             NaN
#
#      Comisión total     ult_act        Pab
# 0               NaN  2025-12-03  484110000
# 1               NaN  2025-12-03  418770000
# 2               NaN         NaN       <NA>
# 3               NaN  2025-12-03  334950000
# 4               NaN  2025-10-23  625500000
# ...             ...         ...        ...
# 5041            NaN         NaN       <NA>
# 5042            NaN         NaN       <NA>
# 5043            NaN         NaN       <NA>
# 5044    42360.58827         NaN       <NA>
# 5045            NaN  2025-11-25  100000000
#
# [5046 rows x 66 columns]

# %%
columnas_finales = [
    "Referencia",
    "Cedula",
    "Nombre del cliente",
    "Id deuda",
    "correo",
    "Banco",
    "Deuda Resuelve",
    "DBT",
    "tipo_cliente",
    "Comisión Mensual",
    "Ahorro",
    "Tipo de cobro",
    "Tipo de Liquidacion",
    "CE",
    "Fecha PL",
    "BANCOS_ESTANDAR",
    "Descuento",
    "P_cierre_Credito_norm",
    "P_Cierre",
    "I_ESPERADO",
    "Negociador",
    "Tipo Elegible",
    "P_Cierre_norm",
    "Días Atraso liquidacion",
    "Estado PL",
    "Ultima Liquidacion",
    "dias_desde_ultima_liq",
    "Priority_level",
    "Apartado neto disponible",
    "Depósitos para 30%",
    "Apartados necesarios Pago Total",
    "Ahorro / Deuda",
    "Comisión total",
    "ult_act",
    "Pab"
]

# Filtrar el dataframe
df_final = df_final[columnas_finales]

# Ver resultado
df_final.head()
print(df_final.shape)
# Out:
# (5046, 35)

# %%
columnas_requeridas = [
    "Apartado neto disponible",
    "Depósitos para 30%",
    "Apartados necesarios Pago Total",
    "Ahorro / Deuda",
    "Comisión total"
]

df_final = df_final.dropna(subset=columnas_requeridas)

# %%
bancos_excluir = [
    'Banco Davivienda',
    'Fincomercio',
    'Mundo Mujer',
    'Comultrasan',
    'Juancho te Presta',
    'JOHN',
    'SisteCredito',
    'Zinobe'
]

df_final = df_final[~df_final["BANCOS_ESTANDAR"].isin(bancos_excluir)]

# %%
df_final
# Out:
#       Referencia      Cedula              Nombre del cliente  Id deuda  \
# 5        5829693     5829693       Rudi Andres lasso Giraldo   1862215
# 6        5829693     5829693       Rudi Andres lasso Giraldo   1862219
# 7        5829693     5829693       Rudi Andres lasso Giraldo   1862218
# 9       10932694    10932694      ARMANDO ILICK HUMANEZ USTA   1922148
# 12      13715630    13715630       FREDY CASTELLANOS HERRENO   1840944
# ...          ...         ...                             ...       ...
# 5032  3507660604    40032509   Maria Consuelo Puerto Hurtado   1935450
# 5033  3507709067    43281300      Gloria Ines Gomez Restrepo   1956015
# 5036  3507978734  1090494112  VICTOR MANUEL PATINO HERNANDEZ   1991440
# 5038  3508329735  1032480298         KAREN DAYANA RUEDA PENA   2016618
# 5044  3508980827    52417868  Norma Katerina Bernier Barliza   1897719
#
#                                correo                 Banco  Deuda Resuelve  \
# 5          rudyandreslasso@hotmail.es             Falabella       1104258.0
# 6          rudyandreslasso@hotmail.es             Av Villas       4468142.0
# 7          rudyandreslasso@hotmail.es  Scotiabank Colpatria       4361500.0
# 9             armandousta@hotmail.com       Banco AV Villas       3383503.0
# 12        martilujosfredy@hotmail.com       Banco Finandina       3308800.0
# ...                               ...                   ...             ...
# 5032               mcph35@hotmail.com                  Itaú       3752700.0
# 5033  gloriagomezrestrepo66@gmail.com         Banco Popular       2328700.0
# 5036       victorpatino1996@gmail.com  Scotiabank Colpatria        652520.0
# 5038            karueda03@hotmail.com             Falabella       1240800.0
# 5044            kata_1977@hotmail.com            Serfinanza       1458600.0
#
#               DBT tipo_cliente  Comisión Mensual  ...  Ultima Liquidacion  \
# 5      49700682.0     bravo_co         249076.20  ...                 NaT
# 6      49700682.0     bravo_co         249076.20  ...                 NaT
# 7      49700682.0     bravo_co         249076.20  ...                 NaT
# 9      73687327.0     bravo_co         363251.44  ...                 NaT
# 12    126055900.0     bravo_co         462519.32  ...                 NaT
# ...           ...          ...               ...  ...                 ...
# 5032   98043730.0     bravo_co         479187.91  ...                 NaT
# 5033   36413800.0     bravo_co         229163.06  ...                 NaT
# 5036    8967483.0     bravo_co          65857.48  ...                 NaT
# 5038   81779500.0     bravo_co              0.00  ...                 NaT
# 5044   16361900.0     bravo_co         109854.26  ...                 NaT
#
#      dias_desde_ultima_liq Priority_level  Apartado neto disponible  \
# 5                      NaN    Prioridad 2                  584505.0
# 6                      NaN    Prioridad 2                  584505.0
# 7                      NaN    Prioridad 1                  584505.0
# 9                      NaN    Prioridad 1                  592480.0
# 12                     NaN    Prioridad 2                 1212976.0
# ...                    ...            ...                       ...
# 5032                   NaN    Prioridad 1                  735671.0
# 5033                   NaN    Prioridad 1                  312212.0
# 5036                   NaN    Prioridad 1                  134894.0
# 5038                   NaN    Prioridad 2                 1027618.0
# 5044                   NaN    Prioridad 1                  225355.0
#
#      Depósitos para 30% Apartados necesarios Pago Total  Ahorro / Deuda  \
# 5              3.618476                        4.046873        0.366569
# 6              4.914433                        1.312742        0.533841
# 7              2.672379                       -0.656472        0.546893
# 9              3.888485                        1.885846        0.418408
# 12             0.624381                        6.184249        0.357856
# ...                 ...                             ...             ...
# 5032           4.246981                        5.448418        0.198052
# 5033           5.482110                        4.741056        0.134340
# 5036           3.418024                        0.803186        0.579294
# 5038           2.034334                        2.114591        0.000172
# 5044           5.963249                        6.094830        0.000000
#
#       Comisión total     ult_act        Pab
# 5        49277.51325  2025-10-23  159000000
# 6       279147.17145         NaN       <NA>
# 7       516132.75000  2025-12-15  147000000
# 9       249634.85134         NaN       <NA>
# 12      225223.39840  2025-09-23  330880000
# ...              ...         ...        ...
# 5032    480064.14750         NaN       <NA>
# 5033    116388.42600         NaN       <NA>
# 5036     36107.19420         NaN       <NA>
# 5038    118124.16000         NaN       <NA>
# 5044     42360.58827         NaN       <NA>
#
# [2044 rows x 35 columns]

# %%
df
# Out:
#        Referencia      Cedula              Nombre del cliente  Id deuda  \
# 0           44032    16539456   Harrinson Arley Cuero Tenorio    629642
# 1           48378    91490364           Alexander Gomez Duran    658347
# 2           48378    91490364           Alexander Gomez Duran    658348
# 3           49322    17658639       Robinson Rodriguez Triana    664009
# 4           51492    31173279       Janeth Jaramillo Gonzalez    680841
# ...           ...         ...                             ...       ...
# 45709  3508859961  1018468661   MAYRA ALEJANDRA HERRERA YEPES   2003472
# 45710  3508980827    52417868  Norma Katerina Bernier Barliza   1897722
# 45711  3508980827    52417868  Norma Katerina Bernier Barliza   1897721
# 45712  3508980827    52417868  Norma Katerina Bernier Barliza   1897719
# 45713  3508980827    52417868  Norma Katerina Bernier Barliza   1897720
#
#                             correo  Deudas Activas            Banco  \
# 0      harry_12tenorio@hotmail.com               1    Banco Popular
# 1       alexgomezduran@hotmail.com               2             BBVA
# 2       alexgomezduran@hotmail.com               2       Davivienda
# 3             rotri_78@hotmail.com               1       Davivienda
# 4        jj_jara_gonzalez@live.com               2       Serfinanza
# ...                            ...             ...              ...
# 45709         mayrahe.ye@gmail.com               2           Zinobe
# 45710        kata_1977@hotmail.com               4      Bancolombia
# 45711        kata_1977@hotmail.com               4  Banco de Bogota
# 45712        kata_1977@hotmail.com               4       Serfinanza
# 45713        kata_1977@hotmail.com               4      Bancolombia
#
#        Número de Crédito  Deuda Resuelve         DBT  ...  P_Cierre  \
# 0               6.60E+08       3834100.0   9750700.0  ...  0.056375
# 1              618794133       4137000.0  59682332.0  ...  0.091274
# 2              400107477       9716000.0  59682332.0  ...  0.042185
# 3      ´5917186000515781       8939539.0  15523006.0  ...  0.040268
# 4              636853406       3239500.0  44920100.0  ...  0.065196
# ...                  ...             ...         ...  ...       ...
# 45709           69248468        279500.0   5111720.0  ...  0.065579
# 45710          990091508       9451200.0  16361900.0  ...  0.126534
# 45711          000091552       2807700.0  16361900.0  ...  0.172227
# 45712          543280844       1458600.0  16361900.0  ...  0.133061
# 45713          530371351       2644400.0  16361900.0  ...  0.182771
#
#           I_ESPERADO                          Negociador  Tipo Elegible  \
# 0       17832.159469           Steven Mateo Aroca Garzon            NaN
# 1       39217.510035           Steven Mateo Aroca Garzon            NaN
# 2       51213.643250           Steven Mateo Aroca Garzon            NaN
# 3       50762.026833    Wendy Vanessa Castillo Velasquez            NaN
# 4       29201.505528  Sharon Natalia Hernandez Dominguez            NaN
# ...              ...                                 ...            ...
# 45709     384.916420            Yithza Camila Paez Lopez            NaN
# 45710  102249.208861           Dayana Isabel Ojito Ortiz            NaN
# 45711   19250.559083           Dayana Isabel Ojito Ortiz            NaN
# 45712    6631.248121           Dayana Isabel Ojito Ortiz            NaN
# 45713   38423.949971           Dayana Isabel Ojito Ortiz            NaN
#
#       P_Cierre_norm Días Atraso liquidacion  Estado PL Ultima Liquidacion  \
# 0          0.281875                   758.0   Atrasado         2022-09-16
# 1          0.456369                  1257.0   Atrasado         2021-11-26
# 2          0.295298                   280.0   Atrasado         2021-11-26
# 3          0.281875                     NaN     Al día         2021-10-25
# 4          0.456369                     NaN     Al día         2022-08-16
# ...             ...                     ...        ...                ...
# 45709      0.459054                   645.0   Atrasado                NaT
# 45710      0.632669                   219.0   Atrasado                NaT
# 45711      0.861133                   690.0   Atrasado                NaT
# 45712      0.931430                   528.0   Atrasado                NaT
# 45713      0.913856                     0.0     Al día                NaT
#
#        dias_desde_ultima_liq  Priority_level
# 0                     1176.0     Prioridad 1
# 1                     1470.0     Prioridad 1
# 2                     1470.0     Prioridad 1
# 3                     1502.0     Prioridad 1
# 4                     1207.0     Prioridad 1
# ...                      ...             ...
# 45709                    NaN     Prioridad 1
# 45710                    NaN     Prioridad 2
# 45711                    NaN     Prioridad 1
# 45712                    NaN     Prioridad 1
# 45713                    NaN     Prioridad 2
#
# [45714 rows x 59 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2044 entries, 5 to 5044
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Referencia                       2044 non-null   object
#  1   Cedula                           2044 non-null   object
#  2   Nombre del cliente               2044 non-null   object
#  3   Id deuda                         2044 non-null   Int64
#  4   correo                           2044 non-null   object
#  5   Banco                            2044 non-null   object
#  6   Deuda Resuelve                   2044 non-null   float64
#  7   DBT                              2044 non-null   float64
#  8   tipo_cliente                     2021 non-null   object
#  9   Comisión Mensual                 2044 non-null   float64
#  10  Ahorro                           2044 non-null   int64
#  11  Tipo de cobro                    2044 non-null   object
#  12  Tipo de Liquidacion              2044 non-null   object
#  13  CE                               2044 non-null   float64
#  14  Fecha PL                         1847 non-null   datetime64[ns]
#  15  BANCOS_ESTANDAR                  2044 non-null   object
#  16  Descuento                        2044 non-null   float64
#  17  P_cierre_Credito_norm            2044 non-null   float64
#  18  P_Cierre                         2044 non-null   float64
#  19  I_ESPERADO                       2044 non-null   float64
#  20  Negociador                       2044 non-null   object
#  21  Tipo Elegible                    0 non-null      float64
#  22  P_Cierre_norm                    2044 non-null   float64
#  23  Días Atraso liquidacion          1847 non-null   float64
#  24  Estado PL                        2044 non-null   object
#  25  Ultima Liquidacion               477 non-null    datetime64[ns]
#  26  dias_desde_ultima_liq            477 non-null    float64
#  27  Priority_level                   2044 non-null   object
#  28  Apartado neto disponible         2044 non-null   float64
#  29  Depósitos para 30%               2044 non-null   float64
#  30  Apartados necesarios Pago Total  2044 non-null   float64
#  31  Ahorro / Deuda                   2044 non-null   float64
#  32  Comisión total                   2044 non-null   float64
#  33  ult_act                          931 non-null    object
#  34  Pab                              931 non-null    Int64
# dtypes: Int64(2), datetime64[ns](2), float64(17), int64(1), object(13)
# memory usage: 578.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45714 entries, 0 to 45713
# Data columns (total 59 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Referencia                 45714 non-null  object
#  1   Cedula                     45710 non-null  object
#  2   Nombre del cliente         45714 non-null  object
#  3   Id deuda                   45714 non-null  int64
#  4   correo                     45714 non-null  object
#  5   Deudas Activas             45714 non-null  int64
#  6   Banco                      45714 non-null  object
#  7   Número de Crédito          45714 non-null  object
#  8   Deuda Resuelve             45714 non-null  float64
#  9   DBT                        45609 non-null  float64
#  10  Meses de atraso            45714 non-null  int64
#  11  Dias de Atraso             45714 non-null  int64
#  12  Apartado Mensual           45609 non-null  float64
#  13  AM/DUM                     45601 non-null  float64
#  14  Fecha inicio               45714 non-null  object
#  15  vehiculo                   45647 non-null  object
#  16  Meses en el Programa       45714 non-null  int64
#  17  tipo_cliente               44042 non-null  object
#  18  Comisión Mensual           45609 non-null  float64
#  19  Ahorro                     45714 non-null  int64
#  20  Tipo de cobro              45714 non-null  object
#  21  Tipo de Liquidacion        45714 non-null  object
#  22  CE                         45609 non-null  float64
#  23  Por Cobrar                 45714 non-null  int64
#  24  Ahorro medio               45706 non-null  float64
#  25  Tiene estructurado         45714 non-null  object
#  26  2XC                        45609 non-null  float64
#  27  Respetable                 8638 non-null   object
#  28  Estado Deuda               45714 non-null  object
#  29  estado_novacion            45714 non-null  object
#  30  ID_reparadora              45714 non-null  int64
#  31  Cartera Activa             45714 non-null  object
#  32  Fecha PL                   41751 non-null  datetime64[ns]
#  33  BANCOS_ESTANDAR            45714 non-null  object
#  34  Descuento                  45714 non-null  float64
#  35  Clasificación Banco        45714 non-null  object
#  36  Apartados 30%              45601 non-null  float64
#  37  Plazo                      45601 non-null  float64
#  38  Estructurable              45714 non-null  int64
#  39  Potencial                  45601 non-null  float64
#  40  # Pagos                    45714 non-null  int64
#  41  P_Pab                      45608 non-null  float64
#  42  S_PAb                      45608 non-null  float64
#  43  Potencial_Estructurados    45608 non-null  float64
#  44  Tipo_Liq_calc              45714 non-null  object
#  45  P_cierre_tradicional       45601 non-null  float64
#  46  P_cierre_Credito           45693 non-null  float64
#  47  P_cierre_tradicional_norm  45714 non-null  float64
#  48  P_cierre_Credito_norm      45714 non-null  float64
#  49  P_Cierre                   45601 non-null  float64
#  50  I_ESPERADO                 45601 non-null  float64
#  51  Negociador                 45714 non-null  object
#  52  Tipo Elegible              0 non-null      float64
#  53  P_Cierre_norm              45601 non-null  float64
#  54  Días Atraso liquidacion    41751 non-null  float64
#  55  Estado PL                  45714 non-null  object
#  56  Ultima Liquidacion         15842 non-null  datetime64[ns]
#  57  dias_desde_ultima_liq      15842 non-null  float64
#  58  Priority_level             45714 non-null  object
# dtypes: datetime64[ns](2), float64(25), int64(10), object(22)
# memory usage: 20.6+ MB

# %%
# Asegurarnos de que estado_novacion sea texto y comparable
df["estado_novacion"] = df["estado_novacion"].astype(str)

# Filtrar referencias con estado NOVACION (sin importar mayúsculas)
refs_novacion = df.loc[
    df["estado_novacion"].str.upper() == "NOVACION",
    "Referencia"
].unique()

# %%
df_final_filtrado = df_final[
    ~df_final["Referencia"].isin(refs_novacion)
].copy()

# %%
df_final = df_final_filtrado.copy()

# %%
df_final
# Out:
#       Referencia      Cedula              Nombre del cliente  Id deuda  \
# 5        5829693     5829693       Rudi Andres lasso Giraldo   1862215
# 6        5829693     5829693       Rudi Andres lasso Giraldo   1862219
# 7        5829693     5829693       Rudi Andres lasso Giraldo   1862218
# 9       10932694    10932694      ARMANDO ILICK HUMANEZ USTA   1922148
# 12      13715630    13715630       FREDY CASTELLANOS HERRENO   1840944
# ...          ...         ...                             ...       ...
# 5032  3507660604    40032509   Maria Consuelo Puerto Hurtado   1935450
# 5033  3507709067    43281300      Gloria Ines Gomez Restrepo   1956015
# 5036  3507978734  1090494112  VICTOR MANUEL PATINO HERNANDEZ   1991440
# 5038  3508329735  1032480298         KAREN DAYANA RUEDA PENA   2016618
# 5044  3508980827    52417868  Norma Katerina Bernier Barliza   1897719
#
#                                correo                 Banco  Deuda Resuelve  \
# 5          rudyandreslasso@hotmail.es             Falabella       1104258.0
# 6          rudyandreslasso@hotmail.es             Av Villas       4468142.0
# 7          rudyandreslasso@hotmail.es  Scotiabank Colpatria       4361500.0
# 9             armandousta@hotmail.com       Banco AV Villas       3383503.0
# 12        martilujosfredy@hotmail.com       Banco Finandina       3308800.0
# ...                               ...                   ...             ...
# 5032               mcph35@hotmail.com                  Itaú       3752700.0
# 5033  gloriagomezrestrepo66@gmail.com         Banco Popular       2328700.0
# 5036       victorpatino1996@gmail.com  Scotiabank Colpatria        652520.0
# 5038            karueda03@hotmail.com             Falabella       1240800.0
# 5044            kata_1977@hotmail.com            Serfinanza       1458600.0
#
#               DBT tipo_cliente  Comisión Mensual  ...  Ultima Liquidacion  \
# 5      49700682.0     bravo_co         249076.20  ...                 NaT
# 6      49700682.0     bravo_co         249076.20  ...                 NaT
# 7      49700682.0     bravo_co         249076.20  ...                 NaT
# 9      73687327.0     bravo_co         363251.44  ...                 NaT
# 12    126055900.0     bravo_co         462519.32  ...                 NaT
# ...           ...          ...               ...  ...                 ...
# 5032   98043730.0     bravo_co         479187.91  ...                 NaT
# 5033   36413800.0     bravo_co         229163.06  ...                 NaT
# 5036    8967483.0     bravo_co          65857.48  ...                 NaT
# 5038   81779500.0     bravo_co              0.00  ...                 NaT
# 5044   16361900.0     bravo_co         109854.26  ...                 NaT
#
#      dias_desde_ultima_liq Priority_level  Apartado neto disponible  \
# 5                      NaN    Prioridad 2                  584505.0
# 6                      NaN    Prioridad 2                  584505.0
# 7                      NaN    Prioridad 1                  584505.0
# 9                      NaN    Prioridad 1                  592480.0
# 12                     NaN    Prioridad 2                 1212976.0
# ...                    ...            ...                       ...
# 5032                   NaN    Prioridad 1                  735671.0
# 5033                   NaN    Prioridad 1                  312212.0
# 5036                   NaN    Prioridad 1                  134894.0
# 5038                   NaN    Prioridad 2                 1027618.0
# 5044                   NaN    Prioridad 1                  225355.0
#
#      Depósitos para 30% Apartados necesarios Pago Total  Ahorro / Deuda  \
# 5              3.618476                        4.046873        0.366569
# 6              4.914433                        1.312742        0.533841
# 7              2.672379                       -0.656472        0.546893
# 9              3.888485                        1.885846        0.418408
# 12             0.624381                        6.184249        0.357856
# ...                 ...                             ...             ...
# 5032           4.246981                        5.448418        0.198052
# 5033           5.482110                        4.741056        0.134340
# 5036           3.418024                        0.803186        0.579294
# 5038           2.034334                        2.114591        0.000172
# 5044           5.963249                        6.094830        0.000000
#
#       Comisión total     ult_act        Pab
# 5        49277.51325  2025-10-23  159000000
# 6       279147.17145         NaN       <NA>
# 7       516132.75000  2025-12-15  147000000
# 9       249634.85134         NaN       <NA>
# 12      225223.39840  2025-09-23  330880000
# ...              ...         ...        ...
# 5032    480064.14750         NaN       <NA>
# 5033    116388.42600         NaN       <NA>
# 5036     36107.19420         NaN       <NA>
# 5038    118124.16000         NaN       <NA>
# 5044     42360.58827         NaN       <NA>
#
# [1774 rows x 35 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1774 entries, 5 to 5044
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Referencia                       1774 non-null   object
#  1   Cedula                           1774 non-null   object
#  2   Nombre del cliente               1774 non-null   object
#  3   Id deuda                         1774 non-null   Int64
#  4   correo                           1774 non-null   object
#  5   Banco                            1774 non-null   object
#  6   Deuda Resuelve                   1774 non-null   float64
#  7   DBT                              1774 non-null   float64
#  8   tipo_cliente                     1754 non-null   object
#  9   Comisión Mensual                 1774 non-null   float64
#  10  Ahorro                           1774 non-null   int64
#  11  Tipo de cobro                    1774 non-null   object
#  12  Tipo de Liquidacion              1774 non-null   object
#  13  CE                               1774 non-null   float64
#  14  Fecha PL                         1606 non-null   datetime64[ns]
#  15  BANCOS_ESTANDAR                  1774 non-null   object
#  16  Descuento                        1774 non-null   float64
#  17  P_cierre_Credito_norm            1774 non-null   float64
#  18  P_Cierre                         1774 non-null   float64
#  19  I_ESPERADO                       1774 non-null   float64
#  20  Negociador                       1774 non-null   object
#  21  Tipo Elegible                    0 non-null      float64
#  22  P_Cierre_norm                    1774 non-null   float64
#  23  Días Atraso liquidacion          1606 non-null   float64
#  24  Estado PL                        1774 non-null   object
#  25  Ultima Liquidacion               208 non-null    datetime64[ns]
#  26  dias_desde_ultima_liq            208 non-null    float64
#  27  Priority_level                   1774 non-null   object
#  28  Apartado neto disponible         1774 non-null   float64
#  29  Depósitos para 30%               1774 non-null   float64
#  30  Apartados necesarios Pago Total  1774 non-null   float64
#  31  Ahorro / Deuda                   1774 non-null   float64
#  32  Comisión total                   1774 non-null   float64
#  33  ult_act                          698 non-null    object
#  34  Pab                              698 non-null    Int64
# dtypes: Int64(2), datetime64[ns](2), float64(17), int64(1), object(13)
# memory usage: 502.4+ KB

# %%
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
import json
import os

# ======================================================
# 1) Detectar entorno y cargar MI_JSON
# ======================================================
def cargar_creds_dict():
    # --- Colab ---
    try:
        from google.colab import userdata
        mi_json = userdata.get("MI_JSON")
        if mi_json:
            print("Entorno detectado: Google Colab")
            return json.loads(mi_json)
    except Exception:
        pass

    # --- GitHub / local ---
    mi_json = os.environ.get("MI_JSON")
    if not mi_json:
        raise ValueError(
            "No encontré MI_JSON.\n"
            "- En Colab: define MI_JSON en Secrets\n"
            "- En GitHub/local: define MI_JSON como variable de entorno"
        )
    print("Entorno detectado: GitHub / local")
    return json.loads(mi_json)

creds_dict = cargar_creds_dict()

# ======================================================
# 2) Cliente gspread (service account)
# ======================================================
gc = gspread.service_account_from_dict(creds_dict)

# ======================================================
# 3) Abrir Google Sheet
# ======================================================
url = "https://docs.google.com/spreadsheets/d/1sMGQCCDiEzZI3f2w5BwFO8iWtxY5AEDJC2dypZ0NrCY/edit#gid=53625301"
sh = gc.open_by_url(url)

# ======================================================
# 4) Eliminar hoja "Priorizar" si existe
# ======================================================
try:
    worksheet_old = sh.worksheet("Priorizar")
    sh.del_worksheet(worksheet_old)
    print("Hoja 'Priorizar' eliminada para reemplazarla.")
except gspread.WorksheetNotFound:
    print("No existía hoja 'Priorizar', se creará nueva.")

# ======================================================
# 5) Crear nueva hoja
# ======================================================
worksheet = sh.add_worksheet(
    title="Priorizar",
    rows=str(len(df_final) + 5),
    cols=str(max(len(df_final.columns) + 5, 20))
)

# ======================================================
# 6) Subir DataFrame
# ======================================================
set_with_dataframe(worksheet, df_final, include_index=False)

print("Hoja 'Priorizar' creada y df_final cargado correctamente.")
# Out:
# Entorno detectado: Google Colab
# Hoja 'Priorizar' eliminada para reemplazarla.
# Hoja 'Priorizar' creada y df_final cargado correctamente.

# %%
import pandas as pd
import gspread
from gspread_dataframe import get_as_dataframe
import json
import os

# ======================================================
# 1) Detectar entorno y cargar MI_JSON
# ======================================================
def cargar_creds_dict():
    # --- Colab ---
    try:
        from google.colab import userdata
        mi_json = userdata.get("MI_JSON")
        if mi_json:
            print("Entorno detectado: Google Colab")
            return json.loads(mi_json)
    except Exception:
        pass

    # --- GitHub / local ---
    mi_json = os.environ.get("MI_JSON")
    if not mi_json:
        raise ValueError(
            "No encontré MI_JSON.\n"
            "- En Colab: define MI_JSON en Secrets\n"
            "- En GitHub/local: define MI_JSON como variable de entorno"
        )
    print("Entorno detectado: GitHub / local")
    return json.loads(mi_json)

creds_dict = cargar_creds_dict()

# ======================================================
# 2) Cliente gspread
# ======================================================
gc = gspread.service_account_from_dict(creds_dict)

# ======================================================
# 3) Abrir Google Sheet por URL
# ======================================================
url = "https://docs.google.com/spreadsheets/d/11xu99MBEZEQ8amR6S66opEXqLN8oMK01r7F5vb1L86M/edit#gid=1973783260"
gid = 1973783260

sh = gc.open_by_url(url)

# ======================================================
# 4) Seleccionar hoja por gid
# ======================================================
worksheet = sh.get_worksheet_by_id(gid)

# ======================================================
# 5) Convertir a DataFrame
# ======================================================
df_11xu99 = get_as_dataframe(worksheet, evaluate_formulas=True)

# Limpieza básica habitual
df_11xu99 = df_11xu99.dropna(how="all")

# ======================================================
# 6) Verificación
# ======================================================
df_11xu99.head()
df_11xu99.info()
# Out:
# Entorno detectado: Google Colab
# <class 'pandas.core.frame.DataFrame'>
# Index: 420 entries, 0 to 419
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   email               419 non-null    object
#  1   employee_id         420 non-null    object
#  2   name                420 non-null    object
#  3   job_title           420 non-null    object
#  4   leader              420 non-null    object
#  5   status              420 non-null    object
#  6   joined_resuelve_on  420 non-null    object
# dtypes: object(7)
# memory usage: 26.2+ KB

# %%
import pandas as pd
import unicodedata

# -----------------------------
# 1. Lista de negociadores
# -----------------------------
negociadores = [
    "Alba Yohana Moreno Martin",
    "Angie Lizeth Cubides Neira",
    "Angela Yara Mayorga",
    "Cindy Vanessa Cruz Rubio",
    "Maria Alejandra Bejarano Tumay",
    "Niyiret Julio Santos",
    "Rosa Yessenia Jimenez Lara",
    "Vivian Caterin Rodriguez Verano",
    "Francy Tatiana Sanchez Fontecha",

    "Dayana Isabel Ojito Ortiz",
    "Diego Alejandro Sanchez Fonseca",
    "Franchesca Julieth Pereira Candela",

    "Hector Elian Lacera Vega",
    "Jana Milena Lopez Buitrago",
    "Mauricio David Valencia Marquez",
    "Norbey Alejandro Duarte Ramirez",
    "Suleimy Tatiana Malaver Niño",
    "Sharon Natalia Hernandez Dominguez",
    "Wendy Vanessa Castillo Velasquez"

]

df_negociadores = pd.DataFrame({"name": negociadores})

# -----------------------------
# 2. Función para normalizar nombres
# -----------------------------
def normalizar_nombre(x):
    if pd.isna(x):
        return ""
    # quitar tildes
    x = unicodedata.normalize('NFKD', x).encode('ascii', 'ignore').decode('utf-8')
    # convertir en minúsculas
    x = x.lower()
    # quitar espacios dobles
    x = " ".join(x.split())
    # capitalizar cada palabra
    x = x.title()
    return x

# -----------------------------
# 3. Normalizar nombres en ambos DF
# -----------------------------
df_negociadores["name_clean"] = df_negociadores["name"].apply(normalizar_nombre)
df_11xu99["name_clean"] = df_11xu99["name"].astype(str).apply(normalizar_nombre)

# -----------------------------
# 4. Merge para obtener correo
# -----------------------------
df_negociadores_correo = df_negociadores.merge(
    df_11xu99[["name_clean", "email"]],
    on="name_clean",
    how="left"
)

# -----------------------------
# 5. Mostrar resultado final
# -----------------------------
print(df_negociadores_correo[["name", "email"]])
# Out:
#                                   name                              email
# 0            Alba Yohana Moreno Martin       yohana.moreno@gobravo.com.co
# 1           Angie Lizeth Cubides Neira       angie.cubides@gobravo.com.co
# 2                  Angela Yara Mayorga          ayara@resuelvetudeuda.com
# 3                  Angela Yara Mayorga         angela.yara@gobravo.com.co
# 4             Cindy Vanessa Cruz Rubio          cindy.cruz@gobravo.com.co
# 5       Maria Alejandra Bejarano Tumay     mariaa.bejarano@gobravo.com.co
# 6                 Niyiret Julio Santos      niyiret.santos@gobravo.com.co
# 7           Rosa Yessenia Jimenez Lara        rosa.jimenez@gobravo.com.co
# 8      Vivian Caterin Rodriguez Verano    vivian.rodriguez@gobravo.com.co
# 9      Francy Tatiana Sanchez Fontecha     tatiana.sanchez@gobravo.com.co
# 10           Dayana Isabel Ojito Ortiz        dayana.ojito@gobravo.com.co
# 11     Diego Alejandro Sanchez Fonseca       diego.sanchez@gobravo.com.co
# 12  Franchesca Julieth Pereira Candela  franchesca.pereira@gobravo.com.co
# 13            Hector Elian Lacera Vega       hector.lacera@gobravo.com.co
# 14          Jana Milena Lopez Buitrago          jana.lopez@gobravo.com.co
# 15     Mauricio David Valencia Marquez    maurcio.valencia@gobravo.com.co
# 16     Norbey Alejandro Duarte Ramirez       norbey.duarte@gobravo.com.co
# 17        Suleimy Tatiana Malaver Niño     suleimy.malaver@gobravo.com.co
# 18  Sharon Natalia Hernandez Dominguez    sharon.hernandez@gobravo.com.co
# 19    Wendy Vanessa Castillo Velasquez      wendy.castillo@gobravo.com.co

# %%
df_negociadores_correo
# Out:
#                                   name                          name_clean  \
# 0            Alba Yohana Moreno Martin           Alba Yohana Moreno Martin
# 1           Angie Lizeth Cubides Neira          Angie Lizeth Cubides Neira
# 2                  Angela Yara Mayorga                 Angela Yara Mayorga
# 3                  Angela Yara Mayorga                 Angela Yara Mayorga
# 4             Cindy Vanessa Cruz Rubio            Cindy Vanessa Cruz Rubio
# 5       Maria Alejandra Bejarano Tumay      Maria Alejandra Bejarano Tumay
# 6                 Niyiret Julio Santos                Niyiret Julio Santos
# 7           Rosa Yessenia Jimenez Lara          Rosa Yessenia Jimenez Lara
# 8      Vivian Caterin Rodriguez Verano     Vivian Caterin Rodriguez Verano
# 9      Francy Tatiana Sanchez Fontecha     Francy Tatiana Sanchez Fontecha
# 10           Dayana Isabel Ojito Ortiz           Dayana Isabel Ojito Ortiz
# 11     Diego Alejandro Sanchez Fonseca     Diego Alejandro Sanchez Fonseca
# 12  Franchesca Julieth Pereira Candela  Franchesca Julieth Pereira Candela
# 13            Hector Elian Lacera Vega            Hector Elian Lacera Vega
# 14          Jana Milena Lopez Buitrago          Jana Milena Lopez Buitrago
# 15     Mauricio David Valencia Marquez     Mauricio David Valencia Marquez
# 16     Norbey Alejandro Duarte Ramirez     Norbey Alejandro Duarte Ramirez
# 17        Suleimy Tatiana Malaver Niño        Suleimy Tatiana Malaver Nino
# 18  Sharon Natalia Hernandez Dominguez  Sharon Natalia Hernandez Dominguez
# 19    Wendy Vanessa Castillo Velasquez    Wendy Vanessa Castillo Velasquez
#
#                                 email
# 0        yohana.moreno@gobravo.com.co
# 1        angie.cubides@gobravo.com.co
# 2           ayara@resuelvetudeuda.com
# 3          angela.yara@gobravo.com.co
# 4           cindy.cruz@gobravo.com.co
# 5      mariaa.bejarano@gobravo.com.co
# 6       niyiret.santos@gobravo.com.co
# 7         rosa.jimenez@gobravo.com.co
# 8     vivian.rodriguez@gobravo.com.co
# 9      tatiana.sanchez@gobravo.com.co
# 10        dayana.ojito@gobravo.com.co
# 11       diego.sanchez@gobravo.com.co
# 12  franchesca.pereira@gobravo.com.co
# 13       hector.lacera@gobravo.com.co
# 14          jana.lopez@gobravo.com.co
# 15    maurcio.valencia@gobravo.com.co
# 16       norbey.duarte@gobravo.com.co
# 17     suleimy.malaver@gobravo.com.co
# 18    sharon.hernandez@gobravo.com.co
# 19      wendy.castillo@gobravo.com.co

# %%
# 1. Marcar si el email pertenece a dominio gobravo
df_negociadores_correo["es_gobravo"] = df_negociadores_correo["email"].astype(str).str.contains("@gobravo.com.co")

# 2. Ordenar dejando primero los correos gobravo
df_negociadores_correo = df_negociadores_correo.sort_values(["name_clean", "es_gobravo"], ascending=[True, False])

# 3. Quitar duplicados quedándonos con el correo correcto
df_negociadores_correo = df_negociadores_correo.drop_duplicates(subset="name_clean", keep="first")

# 4. Limpiar la columna auxiliar
df_negociadores_correo = df_negociadores_correo.drop(columns=["es_gobravo"])

# 5. Ver resultado final
df_negociadores_correo
# Out:
#                                   name                          name_clean  \
# 0            Alba Yohana Moreno Martin           Alba Yohana Moreno Martin
# 3                  Angela Yara Mayorga                 Angela Yara Mayorga
# 1           Angie Lizeth Cubides Neira          Angie Lizeth Cubides Neira
# 4             Cindy Vanessa Cruz Rubio            Cindy Vanessa Cruz Rubio
# 10           Dayana Isabel Ojito Ortiz           Dayana Isabel Ojito Ortiz
# 11     Diego Alejandro Sanchez Fonseca     Diego Alejandro Sanchez Fonseca
# 12  Franchesca Julieth Pereira Candela  Franchesca Julieth Pereira Candela
# 9      Francy Tatiana Sanchez Fontecha     Francy Tatiana Sanchez Fontecha
# 13            Hector Elian Lacera Vega            Hector Elian Lacera Vega
# 14          Jana Milena Lopez Buitrago          Jana Milena Lopez Buitrago
# 5       Maria Alejandra Bejarano Tumay      Maria Alejandra Bejarano Tumay
# 15     Mauricio David Valencia Marquez     Mauricio David Valencia Marquez
# 6                 Niyiret Julio Santos                Niyiret Julio Santos
# 16     Norbey Alejandro Duarte Ramirez     Norbey Alejandro Duarte Ramirez
# 7           Rosa Yessenia Jimenez Lara          Rosa Yessenia Jimenez Lara
# 18  Sharon Natalia Hernandez Dominguez  Sharon Natalia Hernandez Dominguez
# 17        Suleimy Tatiana Malaver Niño        Suleimy Tatiana Malaver Nino
# 8      Vivian Caterin Rodriguez Verano     Vivian Caterin Rodriguez Verano
# 19    Wendy Vanessa Castillo Velasquez    Wendy Vanessa Castillo Velasquez
#
#                                 email
# 0        yohana.moreno@gobravo.com.co
# 3          angela.yara@gobravo.com.co
# 1        angie.cubides@gobravo.com.co
# 4           cindy.cruz@gobravo.com.co
# 10        dayana.ojito@gobravo.com.co
# 11       diego.sanchez@gobravo.com.co
# 12  franchesca.pereira@gobravo.com.co
# 9      tatiana.sanchez@gobravo.com.co
# 13       hector.lacera@gobravo.com.co
# 14          jana.lopez@gobravo.com.co
# 5      mariaa.bejarano@gobravo.com.co
# 15    maurcio.valencia@gobravo.com.co
# 6       niyiret.santos@gobravo.com.co
# 16       norbey.duarte@gobravo.com.co
# 7         rosa.jimenez@gobravo.com.co
# 18    sharon.hernandez@gobravo.com.co
# 17     suleimy.malaver@gobravo.com.co
# 8     vivian.rodriguez@gobravo.com.co
# 19      wendy.castillo@gobravo.com.co

# %%
df_final.columns
# Out:
# Index(['Referencia', 'Cedula', 'Nombre del cliente', 'Id deuda', 'correo',
#        'Banco', 'Deuda Resuelve', 'DBT', 'tipo_cliente', 'Comisión Mensual',
#        'Ahorro', 'Tipo de cobro', 'Tipo de Liquidacion', 'CE', 'Fecha PL',
#        'BANCOS_ESTANDAR', 'Descuento', 'P_cierre_Credito_norm', 'P_Cierre',
#        'I_ESPERADO', 'Negociador', 'Tipo Elegible', 'P_Cierre_norm',
#        'Días Atraso liquidacion', 'Estado PL', 'Ultima Liquidacion',
#        'dias_desde_ultima_liq', 'Priority_level', 'Apartado neto disponible',
#        'Depósitos para 30%', 'Apartados necesarios Pago Total',
#        'Ahorro / Deuda', 'Comisión total', 'ult_act', 'Pab'],
#       dtype='object')

# %% [markdown]
# #ASIGNACION DE ALIANZAS

# %%
# =========================================================
# Leer Google Sheets -> pandas DataFrame (Colab + GitHub)
# Auth: MI_JSON (service account JSON)
# =========================================================

# (1) Instalar dependencias (si ya las tienes, puedes comentar esto)
# En GitHub Actions normalmente van en requirements.txt
# !pip -q install gspread gspread-dataframe google-auth pandas

import os
import json
import pandas as pd
import gspread
from gspread_dataframe import get_as_dataframe

SHEET_URL = "https://docs.google.com/spreadsheets/d/1SoE5xYw_O6DxEmEULaksCFNyUr9j_fPGPDR-0trMIv8/edit?gid=489313072#gid=489313072"
SPREADSHEET_ID = "1SoE5xYw_O6DxEmEULaksCFNyUr9j_fPGPDR-0trMIv8"
GID_TARGET = 489313072

def _load_mi_json() -> dict:
    """
    Devuelve el dict del service account desde MI_JSON.
    - Colab: userdata.get("MI_JSON")
    - GitHub/Local: variable de entorno MI_JSON (como string JSON)
    """
    # Colab
    try:
        from google.colab import userdata  # type: ignore
        mi_json_str = userdata.get("MI_JSON")
        if mi_json_str:
            return json.loads(mi_json_str)
    except Exception:
        pass

    # GitHub/Local (secrets -> env)
    mi_json_str = os.getenv("MI_JSON")
    if not mi_json_str:
        raise ValueError(
            "No encontré MI_JSON. En Colab crea el secreto MI_JSON. "
            "En GitHub agrega MI_JSON en Secrets y pásalo como env."
        )
    return json.loads(mi_json_str)

def _open_gspread_client() -> gspread.Client:
    creds_dict = _load_mi_json()
    return gspread.service_account_from_dict(creds_dict)

def _worksheet_by_gid(sh: gspread.Spreadsheet, gid: int) -> gspread.Worksheet:
    """
    gspread no abre directamente por gid; buscamos la worksheet cuyo id coincide.
    """
    for ws in sh.worksheets():
        if ws.id == gid:
            return ws
    raise ValueError(
        f"No encontré una hoja con gid={gid}. "
        f"GIDs disponibles: {[ws.id for ws in sh.worksheets()]}"
    )

# --- Ejecutar lectura ---
gc = _open_gspread_client()
sh = gc.open_by_key(SPREADSHEET_ID)
ws = _worksheet_by_gid(sh, GID_TARGET)

df_alianzas = get_as_dataframe(ws, evaluate_formulas=True)  # fórmulas -> valores
df_alianzas = df_alianzas.dropna(how="all")                          # quita filas totalmente vacías
df_alianzas.columns = [str(c).strip() for c in df_alianzas.columns]  # limpia nombres de columnas

print("Hoja leída:", ws.title, "| gid:", ws.id)
print("Shape:", df_alianzas.shape)
display(df_alianzas.head(20))  # en Colab se ve bonito; en GitHub imprimirá texto si no hay display
# Out:
# Hoja leída: Diciembre | gid: 489313072
# Shape: (76, 14)
#       REFERENCIA         ID          Banco  Act. septiembre  Act. octubre  \
# 0   3.024402e+09  1658487.0  BBVA Colombia              NaN           NaN
# 1   3.103410e+09  1695087.0  BBVA Colombia              NaN           NaN
# 2   3.104314e+09  1877905.0  BBVA Colombia              NaN           NaN
# 3   3.146195e+09  1714107.0  BBVA Colombia              NaN           NaN
# 4   3.165259e+09  1978653.0  BBVA Colombia              NaN           NaN
# 5   3.103850e+09  1331497.0  BBVA Colombia              NaN           NaN
# 6   3.113582e+09  1668650.0  BBVA Colombia              NaN           NaN
# 7   3.143497e+09  1677597.0  BBVA Colombia              NaN           NaN
# 8   3.117025e+09  1795992.0  BBVA Colombia              NaN           NaN
# 9   3.212269e+09  1906590.0  BBVA Colombia              NaN           NaN
# 10  3.013110e+09  1460505.0  BBVA Colombia              NaN           NaN
# 11  3.115833e+09  1917484.0  BBVA Colombia              NaN           NaN
# 12  2.968118e+07  1906658.0  BBVA Colombia              NaN           NaN
# 13  3.203700e+09  1964962.0  BBVA Colombia              NaN           NaN
# 14  3.104596e+09  1816104.0  BBVA Colombia              NaN           NaN
# 15  3.106037e+09  1970892.0  BBVA Colombia              NaN           NaN
# 16  3.165281e+09  1772108.0  BBVA Colombia              NaN           NaN
# 17  3.135866e+09  1684625.0  BBVA Colombia              NaN           NaN
# 18  3.143024e+09  1936166.0  BBVA Colombia              NaN           NaN
# 19  3.166709e+09  1737414.0  BBVA Colombia              NaN           NaN
#
#     Act. Noviembre  Descuento Actual  descuento_optimo  # PaB óptimos  \
# 0              NaN            0.6072             0.607            1.0
# 1              NaN            0.6075             0.608            1.0
# 2              NaN            0.5559             0.556            1.0
# 3              NaN            0.6367             0.637            1.0
# 4              NaN            0.2536             0.254            1.0
# 5              NaN            0.7531             0.753            1.0
# 6              NaN            0.5966             0.597            1.0
# 7              NaN            0.6327             0.633            1.0
# 8              NaN            0.4850             0.485            2.0
# 9              NaN            0.5490             0.549            2.0
# 10             NaN            0.4308             0.431            2.0
# 11             NaN            0.5839             0.584            2.0
# 12             NaN            0.6534             0.653            2.0
# 13             NaN           -4.7601             0.500            2.0
# 14             NaN            0.6001             0.600            2.0
# 15             NaN            0.7035             0.704            2.0
# 16             NaN            0.4842             0.484            2.0
# 17             NaN           -0.4484             0.636            1.0
# 18             NaN            0.5829             0.583            1.0
# 19             NaN            0.5346             0.535            1.0
#
#     DE a solicitar  Plazo Total Estructurado  Ingreso CE  \
# 0              4.0                       2.0    480141.0
# 1              1.0                       2.0   1259906.0
# 2              6.0                       2.0    120652.0
# 3              NaN                       2.0    344158.0
# 4              4.0                       2.0    546670.0
# 5              NaN                       4.0    315763.0
# 6              7.0                       4.0    834171.0
# 7              5.0                       4.0    731781.0
# 8              4.0                       6.0    578313.0
# 9              6.0                       6.0    669238.0
# 10             7.0                       8.0    437685.0
# 11             4.0                       8.0    325602.0
# 12             7.0                      10.0    827853.0
# 13             7.0                      10.0   1113080.0
# 14             5.0                      11.0   4592693.0
# 15             5.0                      11.0    719920.0
# 16             9.0                      11.0   1132666.0
# 17            33.0                      12.0  10952705.0
# 18            62.0                      12.0   3807036.0
# 19            52.0                      12.0   7272593.0
#
#                             Asignación  Actualizado
# 0            Steven Mateo Aroca Garzon          NaN
# 1             Cindy Vanessa Cruz Rubio          NaN
# 2           Jana Milena Lopez Buitrago          NaN
# 3     Wendy Vanessa Castillo Velasquez          NaN
# 4             Yithza Camila Paez Lopez          NaN
# 5      Vivian Caterin Rodriguez Verano          NaN
# 6                  Angela Yara Mayorga          NaN
# 7            Steven Mateo Aroca Garzon          NaN
# 8      Vivian Caterin Rodriguez Verano          NaN
# 9   Sharon Natalia Hernandez Dominguez          NaN
# 10     Diego Alejandro Sanchez Fonseca          NaN
# 11     Norbey Alejandro Duarte Ramirez          NaN
# 12          Rosa Yessenia Jimenez Lara          NaN
# 13            Yithza Camila Paez Lopez          NaN
# 14        Suleimy Tatiana Malaver Niño          NaN
# 15            Yithza Camila Paez Lopez          NaN
# 16     Vivian Caterin Rodriguez Verano          NaN
# 17                Niyiret Julio Santos          NaN
# 18          Jana Milena Lopez Buitrago          NaN
# 19            Cindy Vanessa Cruz Rubio          NaN

# %%
df_alianzas
# Out:
#       REFERENCIA         ID          Banco  Act. septiembre  Act. octubre  \
# 0   3.024402e+09  1658487.0  BBVA Colombia              NaN           NaN
# 1   3.103410e+09  1695087.0  BBVA Colombia              NaN           NaN
# 2   3.104314e+09  1877905.0  BBVA Colombia              NaN           NaN
# 3   3.146195e+09  1714107.0  BBVA Colombia              NaN           NaN
# 4   3.165259e+09  1978653.0  BBVA Colombia              NaN           NaN
# ..           ...        ...            ...              ...           ...
# 71  3.224347e+09  1937166.0  BBVA Colombia              NaN           NaN
# 72  1.029734e+07  1767187.0  BBVA Colombia              NaN           NaN
# 73  3.104160e+09  1811007.0  BBVA Colombia              NaN           NaN
# 74  3.946364e+07  1908453.0  BBVA Colombia              NaN           NaN
# 75  3.147225e+09  1662035.0  BBVA Colombia              NaN           NaN
#
#     Act. Noviembre  Descuento Actual  descuento_optimo  # PaB óptimos  \
# 0              NaN            0.6072             0.607            1.0
# 1              NaN            0.6075             0.608            1.0
# 2              NaN            0.5559             0.556            1.0
# 3              NaN            0.6367             0.637            1.0
# 4              NaN            0.2536             0.254            1.0
# ..             ...               ...               ...            ...
# 71             NaN            0.4052             0.405            2.0
# 72             NaN           -0.4489             0.588            5.0
# 73             NaN            0.4813             0.481            3.0
# 74             NaN            0.4149             0.415            2.0
# 75             NaN            0.6116             0.612            1.0
#
#     DE a solicitar  Plazo Total Estructurado  Ingreso CE  \
# 0              4.0                       2.0    480141.0
# 1              1.0                       2.0   1259906.0
# 2              6.0                       2.0    120652.0
# 3              NaN                       2.0    344158.0
# 4              4.0                       2.0    546670.0
# ..             ...                       ...         ...
# 71            37.0                      43.0   2101387.0
# 72             9.0                      44.0   4959817.0
# 73            15.0                      47.0   3707083.0
# 74            37.0                      49.0  15341945.0
# 75           999.0                    1000.0    545291.0
#
#                           Asignación  Actualizado
# 0          Steven Mateo Aroca Garzon          NaN
# 1           Cindy Vanessa Cruz Rubio          NaN
# 2         Jana Milena Lopez Buitrago          NaN
# 3   Wendy Vanessa Castillo Velasquez          NaN
# 4           Yithza Camila Paez Lopez          NaN
# ..                               ...          ...
# 71   Norbey Alejandro Duarte Ramirez          NaN
# 72   Mauricio David Valencia Marquez          NaN
# 73   Norbey Alejandro Duarte Ramirez          NaN
# 74               Angela Yara Mayorga          NaN
# 75               Angela Yara Mayorga          NaN
#
# [76 rows x 14 columns]

# %%
df_alianzas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76 entries, 0 to 75
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Referencia                76 non-null     object
#  1   Id deuda                  76 non-null     object
#  2   Banco                     76 non-null     object
#  3   Act. septiembre           0 non-null      float64
#  4   Act. octubre              0 non-null      float64
#  5   Act. Noviembre            0 non-null      float64
#  6   Descuento Actual          76 non-null     float64
#  7   descuento_optimo          76 non-null     float64
#  8   # PaB óptimos             76 non-null     float64
#  9   DE a solicitar            74 non-null     float64
#  10  Plazo Total Estructurado  76 non-null     float64
#  11  Ingreso CE                76 non-null     float64
#  12  Asignación                76 non-null     object
#  13  Actualizado               0 non-null      float64
# dtypes: float64(10), object(4)
# memory usage: 8.9+ KB

# %%
# Renombrar columnas
df_alianzas = df_alianzas.rename(columns={
    "REFERENCIA": "Referencia",
    "ID": "Id deuda"
})

# Convertir a object (string) y quitar el .0
for col in ["Referencia", "Id deuda"]:
    df_alianzas[col] = (
        df_alianzas[col]
        .astype("Int64")   # elimina el .0 de floats tipo 141423.0
        .astype(str)       # pasa a object (string)
    )

# %%
import numpy as np
import pandas as pd

# -------------------------------------------------
# 1. Seleccionar y renombrar columnas de df_alianzas
# -------------------------------------------------
df_nuevas = df_alianzas[[
    "Referencia",
    "Id deuda",
    "Ingreso CE",
    "Plazo Total Estructurado",
    "descuento_optimo",
    "Asignación"
]].rename(columns={
    "Ingreso CE": "Comisión total",
    "Plazo Total Estructurado": "Depósitos para 30%",
    "descuento_optimo": "Descuento",
    "Asignación": "Negociador"
})

# -------------------------------------------------
# 2. Asegurar que tenga TODAS las columnas de df_final
#    (las que no existan quedan en NaN)
# -------------------------------------------------
for col in df_final.columns:
    if col not in df_nuevas.columns:
        df_nuevas[col] = np.nan

# Mantener el mismo orden de columnas
df_nuevas = df_nuevas[df_final.columns]

# -------------------------------------------------
# 3. Concatenar (agregar filas)
# -------------------------------------------------
df_final = pd.concat(
    [df_final, df_nuevas],
    ignore_index=True
)

# -------------------------------------------------
# 4. (Opcional) Verificación rápida
# -------------------------------------------------
print("Filas agregadas:", len(df_nuevas))
print("Nuevo shape df_final:", df_final.shape)
# Out:
# Filas agregadas: 76
# Nuevo shape df_final: (1850, 35)
# /tmp/ipython-input-3164380218.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat(
# /tmp/ipython-input-3164380218.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat(

# %%
df_final
# Out:
#       Referencia    Cedula          Nombre del cliente Id deuda  \
# 0        5829693   5829693   Rudi Andres lasso Giraldo  1862215
# 1        5829693   5829693   Rudi Andres lasso Giraldo  1862219
# 2        5829693   5829693   Rudi Andres lasso Giraldo  1862218
# 3       10932694  10932694  ARMANDO ILICK HUMANEZ USTA  1922148
# 4       13715630  13715630   FREDY CASTELLANOS HERRENO  1840944
# ...          ...       ...                         ...      ...
# 1845  3224346682       NaN                         NaN  1937166
# 1846    10297336       NaN                         NaN  1767187
# 1847  3104159664       NaN                         NaN  1811007
# 1848    39463643       NaN                         NaN  1908453
# 1849  3147225083       NaN                         NaN  1662035
#
#                            correo                 Banco  Deuda Resuelve  \
# 0      rudyandreslasso@hotmail.es             Falabella       1104258.0
# 1      rudyandreslasso@hotmail.es             Av Villas       4468142.0
# 2      rudyandreslasso@hotmail.es  Scotiabank Colpatria       4361500.0
# 3         armandousta@hotmail.com       Banco AV Villas       3383503.0
# 4     martilujosfredy@hotmail.com       Banco Finandina       3308800.0
# ...                           ...                   ...             ...
# 1845                          NaN                   NaN             NaN
# 1846                          NaN                   NaN             NaN
# 1847                          NaN                   NaN             NaN
# 1848                          NaN                   NaN             NaN
# 1849                          NaN                   NaN             NaN
#
#               DBT tipo_cliente  Comisión Mensual  ...  Ultima Liquidacion  \
# 0      49700682.0     bravo_co         249076.20  ...                 NaT
# 1      49700682.0     bravo_co         249076.20  ...                 NaT
# 2      49700682.0     bravo_co         249076.20  ...                 NaT
# 3      73687327.0     bravo_co         363251.44  ...                 NaT
# 4     126055900.0     bravo_co         462519.32  ...                 NaT
# ...           ...          ...               ...  ...                 ...
# 1845          NaN          NaN               NaN  ...                 NaT
# 1846          NaN          NaN               NaN  ...                 NaT
# 1847          NaN          NaN               NaN  ...                 NaT
# 1848          NaN          NaN               NaN  ...                 NaT
# 1849          NaN          NaN               NaN  ...                 NaT
#
#      dias_desde_ultima_liq Priority_level  Apartado neto disponible  \
# 0                      NaN    Prioridad 2                  584505.0
# 1                      NaN    Prioridad 2                  584505.0
# 2                      NaN    Prioridad 1                  584505.0
# 3                      NaN    Prioridad 1                  592480.0
# 4                      NaN    Prioridad 2                 1212976.0
# ...                    ...            ...                       ...
# 1845                   NaN            NaN                       NaN
# 1846                   NaN            NaN                       NaN
# 1847                   NaN            NaN                       NaN
# 1848                   NaN            NaN                       NaN
# 1849                   NaN            NaN                       NaN
#
#      Depósitos para 30% Apartados necesarios Pago Total  Ahorro / Deuda  \
# 0              3.618476                        4.046873        0.366569
# 1              4.914433                        1.312742        0.533841
# 2              2.672379                       -0.656472        0.546893
# 3              3.888485                        1.885846        0.418408
# 4              0.624381                        6.184249        0.357856
# ...                 ...                             ...             ...
# 1845          43.000000                             NaN             NaN
# 1846          44.000000                             NaN             NaN
# 1847          47.000000                             NaN             NaN
# 1848          49.000000                             NaN             NaN
# 1849        1000.000000                             NaN             NaN
#
#       Comisión total     ult_act        Pab
# 0       4.927751e+04  2025-10-23  159000000
# 1       2.791472e+05         NaN       <NA>
# 2       5.161328e+05  2025-12-15  147000000
# 3       2.496349e+05         NaN       <NA>
# 4       2.252234e+05  2025-09-23  330880000
# ...              ...         ...        ...
# 1845    2.101387e+06         NaN       <NA>
# 1846    4.959817e+06         NaN       <NA>
# 1847    3.707083e+06         NaN       <NA>
# 1848    1.534194e+07         NaN       <NA>
# 1849    5.452910e+05         NaN       <NA>
#
# [1850 rows x 35 columns]

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
import json
import os
import unicodedata
import pytz

# Zona horaria Colombia
tz_co = pytz.timezone("America/Bogota")

# ======================================================
# 0) Secrets portables (Colab / GitHub / local)
# ======================================================
def _get_secret(name: str):
    # Colab
    try:
        from google.colab import userdata
        v = userdata.get(name)
        if v is not None and str(v).strip() != "":
            print("Entorno detectado: Google Colab")
            return v
    except Exception:
        pass

    # GitHub / local
    v = os.environ.get(name)
    if v is not None and str(v).strip() != "":
        print("Entorno detectado: GitHub / local")
        return v

    return None

mi_json = _get_secret("MI_JSON")
if not mi_json:
    raise ValueError(
        "No encontré MI_JSON.\n"
        "- En Colab: define MI_JSON en Secrets\n"
        "- En GitHub/local: define MI_JSON como variable de entorno"
    )

gc = gspread.service_account_from_dict(json.loads(mi_json))

# ---------------------------------------
# 1. Normalizador de nombres
# ---------------------------------------
def normalizar_nombre(x):
    if pd.isna(x):
        return ""
    x = unicodedata.normalize("NFKD", str(x)).encode("ascii", "ignore").decode()
    x = " ".join(x.lower().split())
    return x.title()

# ---------------------------------------
# 3. Abrir Sheet de historial "Asignar"
# ---------------------------------------
sheet_url = "https://docs.google.com/spreadsheets/d/1sMGQCCDiEzZI3f2w5BwFO8iWtxY5AEDJC2dypZ0NrCY/edit"
sh = gc.open_by_url(sheet_url)
ws_asignar = sh.worksheet("Asignar")

df_hist = get_as_dataframe(ws_asignar, evaluate_formulas=True).dropna(how="all")

# 🔹 Historial ahora se maneja por Id deuda (NO por Referencia)
if "Id deuda" in df_hist.columns:
    df_hist["Id deuda"] = pd.to_numeric(df_hist["Id deuda"], errors="coerce").astype("Int64")
    ids_previos = set(df_hist["Id deuda"].dropna().tolist())
else:
    ids_previos = set()

# ---------------------------------------
# 4. Preparar df_final (trabajamos por Referencia pero bloqueamos por Id deuda)
# ---------------------------------------
df_final = df_final.copy()

df_final["Referencia"] = pd.to_numeric(df_final["Referencia"], errors="coerce").astype("Int64")
df_final["Id deuda"]   = pd.to_numeric(df_final["Id deuda"], errors="coerce").astype("Int64")

# 🔴 EXCLUIR SIEMPRE LAS REFERENCIAS DE WILLIAM (NO SE ASIGNAN A NADIE)
df_final = df_final[df_final["Negociador"].astype(str) != "William Santiago Abril Esguerra"].copy()

df_final["neg_clean"] = df_final["Negociador"].astype(str).apply(normalizar_nombre)
df_final["ult_act"]   = pd.to_datetime(df_final["ult_act"], errors="coerce")

hoy    = datetime.now().date()
limite = hoy - timedelta(days=60)

df_candidatos = df_final[
    (
        df_final["ult_act"].isna() |
        (df_final["ult_act"].dt.date < limite)
    )
    &
    (~df_final["Id deuda"].isin(ids_previos))
]

# ---------------------------------------
# 5. Lista principal de negociadores válidos
# ---------------------------------------
df_negociadores_correo["name_clean"] = df_negociadores_correo["name"].apply(normalizar_nombre)
lista_principal = df_negociadores_correo["name_clean"].unique().tolist()

# ---------------------------------------
# 6. Fallback
# ---------------------------------------
fallback_pool = df_candidatos[~df_candidatos["neg_clean"].isin(lista_principal)].copy()

# ---------------------------------------
# 7. Asignación diaria (3 REFERENCIAS por negociador principal)
# ---------------------------------------
asignaciones = []
referencias_asignadas_run = set()

for neg in lista_principal:
    pool = df_candidatos[
        (df_candidatos["neg_clean"] == neg) &
        (~df_candidatos["Referencia"].isin(referencias_asignadas_run))
    ].copy()

    pool = pool.sort_values(by=["Comisión total", "Ahorro"], ascending=False)
    pool = pool.drop_duplicates(subset="Referencia", keep="first")

    seleccion = pool.head(3)
    faltan = 3 - len(seleccion)

    if faltan > 0:
        pool_fb = fallback_pool[
            ~fallback_pool["Referencia"].isin(referencias_asignadas_run)
        ].copy()
        pool_fb = pool_fb.sort_values(by=["Comisión total", "Ahorro"], ascending=False)
        pool_fb = pool_fb.drop_duplicates(subset="Referencia", keep="first")

        fb_take = pool_fb.head(faltan)
        seleccion = pd.concat([seleccion, fb_take])

        fallback_pool = fallback_pool[~fallback_pool["Referencia"].isin(fb_take["Referencia"])]

    if len(seleccion) < 3:
        print(f"⚠️ {neg} no tiene suficientes referencias disponibles. No se asigna hoy.")
        continue

    referencias_asignadas_run.update(seleccion["Referencia"].tolist())

    seleccion = seleccion.copy()
    seleccion["Negociador asignado"] = neg

    email = df_negociadores_correo.loc[df_negociadores_correo["name_clean"] == neg, "email"].iloc[0]
    seleccion["Email asignado"] = email
    seleccion["Fecha asignación"] = datetime.now(tz_co).strftime("%Y-%m-%d %H:%M:%S")
    seleccion["Negociador original"] = seleccion["Negociador"]

    asignaciones.append(seleccion)

if len(asignaciones) == 0:
    print("⚠️ No se generaron asignaciones hoy.")
    df_asignar_hoy = pd.DataFrame(columns=df_final.columns.tolist() + [
        "Negociador asignado", "Email asignado", "Fecha asignación", "Negociador original"
    ])
else:
    df_asignar_hoy = pd.concat(asignaciones, ignore_index=True)

# ---------------------------------------
# 8. Columnas finales del Sheet
# ---------------------------------------
columnas_finales_sheet = [
    "Negociador asignado",
    "Email asignado",
    "Negociador original",
    "Fecha asignación",
    "ult_act",
    "Referencia",
    "Id deuda",
    "Depósitos para 30%",
    "Comisión total",
    "Descuento"
]

df_asignar_hoy_sheet = df_asignar_hoy[columnas_finales_sheet]

df_hist_sheet = (
    df_hist[columnas_finales_sheet]
    if len(df_hist) > 0
    else pd.DataFrame(columns=columnas_finales_sheet)
)

df_total_sheet = pd.concat([df_asignar_hoy_sheet, df_hist_sheet], ignore_index=True)

# ---------------------------------------
# 9. ESCRIBIR ASIGNACIONES
# ---------------------------------------
ws_asignar.clear()
set_with_dataframe(ws_asignar, df_total_sheet)
print("✔ Asignaciones agregadas en la hoja 'Asignar'")
print("➡ Filas nuevas agregadas:", len(df_asignar_hoy_sheet))

# ---------------------------------------
# 10. AGREGAR COLUMNA ¿Se actualizó?
# ---------------------------------------
df_12098["bank_reference"] = pd.to_numeric(df_12098["bank_reference"], errors="coerce").astype("Int64")

def limpiar_fecha(x):
    try:
        return pd.to_datetime(x).date()
    except Exception:
        return pd.NaT

df_12098["inserted_at"] = df_12098["inserted_at"].apply(limpiar_fecha)
df_12098_valid = df_12098.dropna(subset=["inserted_at", "bank_reference"])

ult_act_dict = df_12098_valid.groupby("bank_reference")["inserted_at"].max().to_dict()

df_total_sheet["Fila vieja?"] = 0
df_total_sheet.loc[len(df_asignar_hoy_sheet):, "Fila vieja?"] = 1

def verificar_actualizacion(row):
    if row["Fila vieja?"] == 0:
        return ""

    ref = row["Referencia"]
    asign = row["Fecha asignación"]

    try:
        asign = pd.to_datetime(asign).date()
    except Exception:
        return "Fecha asignación inválida"

    if pd.isna(ref):
        return "Sin información"

    if ref not in ult_act_dict:
        return "Sin información"

    inserted = ult_act_dict[ref]
    return "Sí se actualizó" if inserted > asign else "No se actualizó"

df_total_sheet["¿Se actualizó?"] = df_total_sheet.apply(verificar_actualizacion, axis=1)
df_total_sheet = df_total_sheet.drop(columns=["Fila vieja?"])

# ---------------------------------------
# 11. REESCRIBIR HOJA CON COLUMNA ¿Se actualizó?
# ---------------------------------------
ws_asignar.clear()
set_with_dataframe(ws_asignar, df_total_sheet)
print("✔ Columna '¿Se actualizó?' agregada correctamente.")
# Out:
# Entorno detectado: Google Colab
# ✔ Asignaciones agregadas en la hoja 'Asignar'
# ➡ Filas nuevas agregadas: 57
# ✔ Columna '¿Se actualizó?' agregada correctamente.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import json
import os
import pytz
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# ======================================================
# 0) Secrets portables (Colab / GitHub / local)
# ======================================================
def _get_secret(name: str):
    try:
        from google.colab import userdata
        v = userdata.get(name)
        if v is not None and str(v).strip() != "":
            return v
    except Exception:
        pass
    v = os.environ.get(name)
    if v is not None and str(v).strip() != "":
        return v
    return None

mi_json = _get_secret("MI_JSON")
if not mi_json:
    raise ValueError(
        "No encontré MI_JSON.\n"
        "- En Colab: define MI_JSON en Secrets\n"
        "- En GitHub/local: define MI_JSON como variable de entorno"
    )

# Zona horaria Colombia (portable)
tz_co = pytz.timezone("America/Bogota")

# Conectar a Sheets (portable)
gc = gspread.service_account_from_dict(json.loads(mi_json))

sheet_url = "https://docs.google.com/spreadsheets/d/1sMGQCCDiEzZI3f2w5BwFO8iWtxY5AEDJC2dypZ0NrCY/edit"
sh = gc.open_by_url(sheet_url)

# ---------------------------------------
# NUEVO BLOQUE: Resumen para Bot por negociador (solo HOY)
# ---------------------------------------

# Volvemos a leer la hoja 'Asignar' ya actualizada
ws_asignar = sh.worksheet("Asignar")
df_asignar = get_as_dataframe(ws_asignar, evaluate_formulas=True).dropna(how="all")

# Aseguramos que existe 'Fecha asignación'
if "Fecha asignación" not in df_asignar.columns:
    raise ValueError("La hoja 'Asignar' no tiene la columna 'Fecha asignación'.")

# Parsear Fecha asignación a datetime
df_asignar["Fecha asignación"] = pd.to_datetime(df_asignar["Fecha asignación"], errors="coerce")

# Día de hoy (zona horaria Colombia)
hoy_co = datetime.now(tz_co).date()

# Filtrar solo filas de hoy
df_hoy = df_asignar[df_asignar["Fecha asignación"].dt.date == hoy_co].copy()

# Si no hay filas para hoy → DF vacío con estructura final
if df_hoy.empty:
    print("⚠️ No hay asignaciones para el día de hoy en la hoja 'Asignar'.")
    df_bot = pd.DataFrame(columns=[
        "Negociador asignado",
        "Email asignado",
        "Fecha asignación",
        "Mensaje"
    ])
else:
    columnas_necesarias = [
        "Negociador asignado",
        "Email asignado",
        "Fecha asignación",
        "Referencia",
        "Id deuda",
        "Depósitos para 30%",
        "Comisión total",
        "Descuento"
    ]
    for col in columnas_necesarias:
        if col not in df_hoy.columns:
            df_hoy[col] = np.nan

    # Tipos
    df_hoy["Referencia"] = pd.to_numeric(df_hoy["Referencia"], errors="coerce").astype("Int64")
    df_hoy["Id deuda"]   = pd.to_numeric(df_hoy["Id deuda"], errors="coerce").astype("Int64")
    for col_num in ["Depósitos para 30%", "Comisión total", "Descuento"]:
        df_hoy[col_num] = pd.to_numeric(df_hoy[col_num], errors="coerce")

    # Construir una línea de detalle por cada fila
    def construir_linea(row):
        ref   = row["Referencia"]
        deuda = row["Id deuda"]
        dep   = row["Depósitos para 30%"]
        com   = row["Comisión total"]
        desc  = row["Descuento"]

        ref_txt   = f"{ref}" if pd.notna(ref) else "N/A"
        deuda_txt = f"{deuda}" if pd.notna(deuda) else "N/A"
        dep_txt   = f"{dep:,.0f}" if pd.notna(dep) else "N/A"
        com_txt   = f"{com:,.0f}" if pd.notna(com) else "N/A"
        desc_txt  = f"{desc:.2%}" if pd.notna(desc) else "N/A"

        return (
            f"Referencia: {ref_txt} | "
            f"Id deuda: {deuda_txt} | "
            f"Depósitos 30%: {dep_txt} | "
            f"Comisión total: {com_txt} | "
            f"Descuento: {desc_txt}"
        )

    df_hoy["Detalle"] = df_hoy.apply(construir_linea, axis=1)

    # Agrupar y unir líneas
    df_bot = (
        df_hoy
        .groupby(["Negociador asignado", "Email asignado", "Fecha asignación"], as_index=False)
        .agg({"Detalle": lambda x: "\n".join(x)})
        .rename(columns={"Detalle": "Mensaje"})
    )

    df_bot = df_bot[["Negociador asignado", "Email asignado", "Fecha asignación", "Mensaje"]]

# ---------------------------------------
# Escribir SIEMPRE la hoja 'Asignar Bot'
# ---------------------------------------
try:
    ws_bot = sh.worksheet("Asignar Bot")
except gspread.WorksheetNotFound:
    ws_bot = sh.add_worksheet(title="Asignar Bot", rows="100", cols="10")

ws_bot.clear()
set_with_dataframe(ws_bot, df_bot, include_index=False)

print("✔ Hoja 'Asignar Bot' actualizada con los mensajes por negociador del día de hoy.")
# Out:
# ✔ Hoja 'Asignar Bot' actualizada con los mensajes por negociador del día de hoy.

# %% [markdown]
# #Seguimiento

# %%
import json
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials

# =====================================
# 1. Cargar MI_JSON (Colab / GitHub)
# =====================================
try:
    from google.colab import userdata
    mi_json = userdata.get("MI_JSON")
except ImportError:
    import os
    mi_json = os.environ.get("MI_JSON")

if mi_json is None:
    raise ValueError("MI_JSON no encontrado")

creds_dict = json.loads(mi_json)

scopes = ["https://www.googleapis.com/auth/spreadsheets.readonly"]
creds = Credentials.from_service_account_info(creds_dict, scopes=scopes)

gc = gspread.authorize(creds)

# =====================================
# 2. Abrir Sheet
# =====================================
SPREADSHEET_ID = "1O8OHuVhgwhLw8XYEBf1uBzLYrxQ45rPiZecHOnAa1Go"
GID = 1739799528

sh = gc.open_by_key(SPREADSHEET_ID)
ws = sh.get_worksheet_by_id(GID)
df_act = pd.DataFrame(ws.get_all_records())

# %%
df_act
# Out:
#        expiration                                       observations  \
# 0                  Stefy 8086 // 7:22 // Se valida en chat de tuy...
# 1                  7:22 a. m. 02/01/2025 VivianR//8522// Crédito ...
# 2                  YesseniaJ|8045|02-01-2025|9:07am|llamo a tt pa...
# 3                  Actividad para Nicolle Stefy 8086 // 10:52 // ...
# 4                  7:22 a. m. 02/01/2025 VivianR//8522// Crédito ...
# ...           ...                                                ...
# 280697             Jana||6:00 p. m. 16/12/2025 se recibe acuerdo ...
# 280698             6:13 p. m. 16/12/2025 VivianR// Adjunto acuerd...
# 280699             Jana || 5:06 p. m. 16/12/2025 lina salaz  #625...
# 280700             \nYoha/6:17pm //se valida en chat systemgroup ...
# 280701             \nYoha/6:17pm //se valida en chat systemgroup ...
#
#                                     end  debt_id   payment_to_bank  \
# 0          stefany.rojas@gobravo.com.co  1508614   (551000000,COP)
# 1       vivian.rodriguez@gobravo.com.co  1186799   (500000000,COP)
# 2           rosa.jimenez@gobravo.com.co  1305562    (54700000,COP)
# 3          stefany.rojas@gobravo.com.co   873948  (2600000000,COP)
# 4       vivian.rodriguez@gobravo.com.co  1450752   (573800000,COP)
# ...                                 ...      ...               ...
# 280697        jana.lopez@gobravo.com.co  1668586   (266057900,COP)
# 280698  vivian.rodriguez@gobravo.com.co  1331497    (58000000,COP)
# 280699        jana.lopez@gobravo.com.co  1829745   (574461400,COP)
# 280700     yohana.moreno@gobravo.com.co  1756285   (300000000,COP)
# 280701     yohana.moreno@gobravo.com.co  1756284    (80000000,COP)
#
#                 inserted_at  bank_reference
# 0       2025-01-02 12:23:03        51911010
# 1       2025-01-02 12:48:27      3108379218
# 2       2025-01-02 14:08:00      3103940951
# 3       2025-01-02 15:58:43      3158318257
# 4       2025-01-02 12:44:39      3022621202
# ...                     ...             ...
# 280697  2025-12-16 23:04:02      3157251856
# 280698  2025-12-16 23:14:01      3103849795
# 280699  2025-12-16 23:18:45      3161052468
# 280700  2025-12-16 23:19:24      1130625305
# 280701  2025-12-16 23:20:10      1130625305
#
# [280702 rows x 7 columns]

# %%
import json
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials

# =====================================
# 1. Cargar MI_JSON (Colab / GitHub)
# =====================================
try:
    from google.colab import userdata
    mi_json = userdata.get("MI_JSON")
except ImportError:
    import os
    mi_json = os.environ.get("MI_JSON")

if mi_json is None:
    raise ValueError("MI_JSON no encontrado")

creds_dict = json.loads(mi_json)

scopes = ["https://www.googleapis.com/auth/spreadsheets.readonly"]
creds = Credentials.from_service_account_info(creds_dict, scopes=scopes)

gc = gspread.authorize(creds)

# =====================================
# 2. Abrir Sheet
# =====================================
SPREADSHEET_ID = "1sMGQCCDiEzZI3f2w5BwFO8iWtxY5AEDJC2dypZ0NrCY"
GID = 1129967215

sh = gc.open_by_key(SPREADSHEET_ID)
ws = sh.get_worksheet_by_id(GID)
df_seg = pd.DataFrame(ws.get_all_records())

# %%
df_seg
# Out:
#                   Negociador asignado                   Email asignado  \
# 0           Alba Yohana Moreno Martin     yohana.moreno@gobravo.com.co
# 1           Alba Yohana Moreno Martin     yohana.moreno@gobravo.com.co
# 2           Alba Yohana Moreno Martin     yohana.moreno@gobravo.com.co
# 3                 Angela Yara Mayorga       angela.yara@gobravo.com.co
# 4                 Angela Yara Mayorga       angela.yara@gobravo.com.co
# ..                                ...                              ...
# 292   Vivian Caterin Rodriguez Verano  vivian.rodriguez@gobravo.com.co
# 293   Vivian Caterin Rodriguez Verano  vivian.rodriguez@gobravo.com.co
# 294  Wendy Vanessa Castillo Velasquez    wendy.castillo@gobravo.com.co
# 295  Wendy Vanessa Castillo Velasquez    wendy.castillo@gobravo.com.co
# 296  Wendy Vanessa Castillo Velasquez    wendy.castillo@gobravo.com.co
#
#                   Negociador original     Fecha asignación  \
# 0           Alba Yohana Moreno Martin   2025-12-17 8:14:34
# 1           Alba Yohana Moreno Martin   2025-12-17 8:14:34
# 2           Alba Yohana Moreno Martin   2025-12-17 8:14:34
# 3                 Angela Yara Mayorga   2025-12-17 8:14:34
# 4                 Angela Yara Mayorga   2025-12-17 8:14:34
# ..                                ...                  ...
# 292   Vivian Caterin Rodriguez Verano  2025-12-11 12:25:22
# 293   Vivian Caterin Rodriguez Verano  2025-12-11 12:25:22
# 294  Wendy Vanessa Castillo Velasquez  2025-12-11 12:25:22
# 295  Wendy Vanessa Castillo Velasquez  2025-12-11 12:25:22
# 296  Wendy Vanessa Castillo Velasquez  2025-12-11 12:25:22
#
#                 ult_act  Referencia  Id deuda  Depósitos para 30%  \
# 0                        3188811171   1883138                  27
# 1                        3206158037   1931847          2233430908
# 2    2025-08-25 0:00:00    79249358   1835885          2707411046
# 3                          39463643   1908453                  49
# 4                        3054200634   1744144                  29
# ..                  ...         ...       ...                 ...
# 292  2025-09-19 0:00:00    94315912   1745159          1907272358
# 293                      3163937546   1950291          2677885346
# 294                      3117293523   1921130          5809857922
# 295                      3168693335   1831247          5422921029
# 296                      3105839709   2029933          3282444979
#
#      Comisión total  Descuento   ¿Se actualizó?
# 0          16531920        447
# 1          36755411         43
# 2         358477028         38
# 3          15341945        415
# 4           1032470         36
# ..              ...        ...              ...
# 292      2044856968         62  Sí se actualizó
# 293      1734266016         48  No se actualizó
# 294        29640996          6  Sí se actualizó
# 295      1003761241       6987  Sí se actualizó
# 296       894635209       7033  No se actualizó
#
# [297 rows x 11 columns]

# %%
df_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Negociador asignado  297 non-null    object
#  1   Email asignado       297 non-null    object
#  2   Negociador original  297 non-null    object
#  3   Fecha asignación     297 non-null    object
#  4   ult_act              297 non-null    object
#  5   Referencia           297 non-null    int64
#  6   Id deuda             297 non-null    int64
#  7   Depósitos para 30%   297 non-null    int64
#  8   Comisión total       297 non-null    int64
#  9   Descuento            297 non-null    int64
#  10  ¿Se actualizó?       297 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 25.7+ KB

# %%
df_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280702 entries, 0 to 280701
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   expiration       280702 non-null  object
#  1   observations     280702 non-null  object
#  2   end              280702 non-null  object
#  3   debt_id          280702 non-null  int64
#  4   payment_to_bank  280702 non-null  object
#  5   inserted_at      280702 non-null  object
#  6   bank_reference   280702 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 15.0+ MB

# %%
import pandas as pd

# Copia de seguridad
df_seg = df_seg.copy()

# Normalizar nombres de columnas (por si vienen con espacios raros)
df_seg.columns = (
    df_seg.columns
    .str.strip()
)

# Fecha asignación a datetime
df_seg["Fecha asignación"] = pd.to_datetime(
    df_seg["Fecha asignación"],
    errors="coerce"
)

# Referencia e Id deuda como texto (clave)
df_seg["Referencia"] = df_seg["Referencia"].astype(str)
df_seg["Id deuda"] = df_seg["Id deuda"].astype(str)

# %%
# Quedarse únicamente con las columnas necesarias
cols = [
    "Negociador asignado",
    "Fecha asignación",
    "Referencia",
    "Id deuda"
]

df_seg = df_seg[cols].copy()

# %%
df_seg
# Out:
#                   Negociador asignado    Fecha asignación  Referencia Id deuda
# 0           Alba Yohana Moreno Martin 2025-12-17 08:14:34  3188811171  1883138
# 1           Alba Yohana Moreno Martin 2025-12-17 08:14:34  3206158037  1931847
# 2           Alba Yohana Moreno Martin 2025-12-17 08:14:34    79249358  1835885
# 3                 Angela Yara Mayorga 2025-12-17 08:14:34    39463643  1908453
# 4                 Angela Yara Mayorga 2025-12-17 08:14:34  3054200634  1744144
# ..                                ...                 ...         ...      ...
# 292   Vivian Caterin Rodriguez Verano 2025-12-11 12:25:22    94315912  1745159
# 293   Vivian Caterin Rodriguez Verano 2025-12-11 12:25:22  3163937546  1950291
# 294  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3117293523  1921130
# 295  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3168693335  1831247
# 296  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3105839709  2029933
#
# [297 rows x 4 columns]

# %%
df_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280702 entries, 0 to 280701
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   expiration       280702 non-null  object
#  1   observations     280702 non-null  object
#  2   end              280702 non-null  object
#  3   debt_id          280702 non-null  int64
#  4   payment_to_bank  280702 non-null  object
#  5   inserted_at      280702 non-null  object
#  6   bank_reference   280702 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 15.0+ MB

# %%
import pandas as pd

# Copia por seguridad
df_act = df_act.copy()

# Convertir a object (string)
df_act["bank_reference"] = df_act["bank_reference"].astype(str)
df_act["debt_id"] = df_act["debt_id"].astype(str)

# Convertir inserted_at a datetime
df_act["inserted_at"] = pd.to_datetime(
    df_act["inserted_at"],
    errors="coerce"
)

# Renombrar columnas
df_act = df_act.rename(columns={
    "bank_reference": "Referencia",
    "debt_id": "Id deuda",
    "inserted_at": "Fecha act"
})

# %%
df_act
# Out:
#        expiration                                       observations  \
# 0                  Stefy 8086 // 7:22 // Se valida en chat de tuy...
# 1                  7:22 a. m. 02/01/2025 VivianR//8522// Crédito ...
# 2                  YesseniaJ|8045|02-01-2025|9:07am|llamo a tt pa...
# 3                  Actividad para Nicolle Stefy 8086 // 10:52 // ...
# 4                  7:22 a. m. 02/01/2025 VivianR//8522// Crédito ...
# ...           ...                                                ...
# 280697             Jana||6:00 p. m. 16/12/2025 se recibe acuerdo ...
# 280698             6:13 p. m. 16/12/2025 VivianR// Adjunto acuerd...
# 280699             Jana || 5:06 p. m. 16/12/2025 lina salaz  #625...
# 280700             \nYoha/6:17pm //se valida en chat systemgroup ...
# 280701             \nYoha/6:17pm //se valida en chat systemgroup ...
#
#                                     end Id deuda   payment_to_bank  \
# 0          stefany.rojas@gobravo.com.co  1508614   (551000000,COP)
# 1       vivian.rodriguez@gobravo.com.co  1186799   (500000000,COP)
# 2           rosa.jimenez@gobravo.com.co  1305562    (54700000,COP)
# 3          stefany.rojas@gobravo.com.co   873948  (2600000000,COP)
# 4       vivian.rodriguez@gobravo.com.co  1450752   (573800000,COP)
# ...                                 ...      ...               ...
# 280697        jana.lopez@gobravo.com.co  1668586   (266057900,COP)
# 280698  vivian.rodriguez@gobravo.com.co  1331497    (58000000,COP)
# 280699        jana.lopez@gobravo.com.co  1829745   (574461400,COP)
# 280700     yohana.moreno@gobravo.com.co  1756285   (300000000,COP)
# 280701     yohana.moreno@gobravo.com.co  1756284    (80000000,COP)
#
#                  Fecha act  Referencia
# 0      2025-01-02 12:23:03    51911010
# 1      2025-01-02 12:48:27  3108379218
# 2      2025-01-02 14:08:00  3103940951
# 3      2025-01-02 15:58:43  3158318257
# 4      2025-01-02 12:44:39  3022621202
# ...                    ...         ...
# 280697 2025-12-16 23:04:02  3157251856
# 280698 2025-12-16 23:14:01  3103849795
# 280699 2025-12-16 23:18:45  3161052468
# 280700 2025-12-16 23:19:24  1130625305
# 280701 2025-12-16 23:20:10  1130625305
#
# [280702 rows x 7 columns]

# %%
import pandas as pd
import numpy as np

# -----------------------------
# 0) Copias y tipos
# -----------------------------
df_seg = df_seg.copy()
df_act = df_act.copy()

# Llaves como texto
for c in ["Id deuda", "Referencia"]:
    if c in df_seg.columns:
        df_seg[c] = df_seg[c].astype(str)
    if c in df_act.columns:
        df_act[c] = df_act[c].astype(str)

# Fechas
df_seg["Fecha asignación"] = pd.to_datetime(df_seg["Fecha asignación"], errors="coerce")

# df_act: asegurar Fecha act
if "Fecha act" not in df_act.columns:
    if "Fecha asignación" in df_act.columns:
        df_act["Fecha act"] = pd.to_datetime(df_act["Fecha asignación"], errors="coerce")
    elif "inserted_at" in df_act.columns:
        df_act["Fecha act"] = pd.to_datetime(df_act["inserted_at"], errors="coerce")
    else:
        raise ValueError("df_act no tiene 'Fecha act' ni una alternativa ('Fecha asignación' o 'inserted_at').")

df_act["Fecha act"] = pd.to_datetime(df_act["Fecha act"], errors="coerce")

# Comparación por día (sin hora)
df_seg["_fa_dia"] = df_seg["Fecha asignación"].dt.floor("D")
df_act["_fact_dia"] = df_act["Fecha act"].dt.floor("D")

# -----------------------------
# 1) MATCH 1: por Id deuda (Esa deuda)
# -----------------------------
tmp_deuda = df_seg[["Id deuda", "Fecha asignación", "_fa_dia"]].merge(
    df_act[["Id deuda", "Fecha act", "_fact_dia", "observations"]],
    on="Id deuda",
    how="left"
)

tmp_deuda_val = tmp_deuda[
    tmp_deuda["Fecha act"].notna()
    & tmp_deuda["_fa_dia"].notna()
    & (tmp_deuda["_fact_dia"] >= tmp_deuda["_fa_dia"])
].copy()

tmp_deuda_val = tmp_deuda_val.sort_values(["Id deuda", "Fecha asignación", "Fecha act"])
best_deuda = tmp_deuda_val.drop_duplicates(subset=["Id deuda", "Fecha asignación"], keep="first")

df_seg = df_seg.merge(
    best_deuda[["Id deuda", "Fecha asignación", "Fecha act", "observations"]],
    on=["Id deuda", "Fecha asignación"],
    how="left",
    suffixes=("", "")
)

# Crear columna como texto (dtype object) y luego asignar
df_seg["que?"] = pd.NA
mask_esa = df_seg["Fecha act"].notna() | df_seg["observations"].notna()
df_seg.loc[mask_esa, "que?"] = "Esa deuda"

# -----------------------------
# 2) MATCH 2: fallback por Referencia (Otra deuda)
#     Solo para filas que siguen sin gestión
# -----------------------------
mask_falta = df_seg["Fecha act"].isna() & df_seg["observations"].isna()

tmp_ref = df_seg.loc[mask_falta, ["Referencia", "Fecha asignación", "_fa_dia"]].merge(
    df_act[["Referencia", "Fecha act", "_fact_dia", "observations"]],
    on="Referencia",
    how="left"
)

tmp_ref_val = tmp_ref[
    tmp_ref["Fecha act"].notna()
    & tmp_ref["_fa_dia"].notna()
    & (tmp_ref["_fact_dia"] >= tmp_ref["_fa_dia"])
].copy()

# Elegir la Fecha act más cercana (mínima) para esa Referencia + Fecha asignación
tmp_ref_val = tmp_ref_val.sort_values(["Referencia", "Fecha asignación", "Fecha act"])
best_ref = tmp_ref_val.drop_duplicates(subset=["Referencia", "Fecha asignación"], keep="first")

# Volver a pegarlo en df_seg SOLO para las filas faltantes
df_seg = df_seg.merge(
    best_ref[["Referencia", "Fecha asignación", "Fecha act", "observations"]],
    on=["Referencia", "Fecha asignación"],
    how="left",
    suffixes=("", "_ref")
)

# Si se llenó por referencia, reemplazamos los nulos originales
df_seg["Fecha act"] = df_seg["Fecha act"].combine_first(df_seg["Fecha act_ref"])
df_seg["observations"] = df_seg["observations"].combine_first(df_seg["observations_ref"])

# Marcar "que?" como Otra deuda donde se completó por referencia
df_seg.loc[
    mask_falta & (df_seg["Fecha act_ref"].notna() | df_seg["observations_ref"].notna()),
    "que?"
] = "Otra deuda"

# Limpiar auxiliares
df_seg = df_seg.drop(columns=["_fa_dia", "Fecha act_ref", "observations_ref"], errors="ignore")
df_act = df_act.drop(columns=["_fact_dia"], errors="ignore")

# %%
df_seg
# Out:
#                   Negociador asignado    Fecha asignación  Referencia  \
# 0           Alba Yohana Moreno Martin 2025-12-17 08:14:34  3188811171
# 1           Alba Yohana Moreno Martin 2025-12-17 08:14:34  3206158037
# 2           Alba Yohana Moreno Martin 2025-12-17 08:14:34    79249358
# 3                 Angela Yara Mayorga 2025-12-17 08:14:34    39463643
# 4                 Angela Yara Mayorga 2025-12-17 08:14:34  3054200634
# ..                                ...                 ...         ...
# 292   Vivian Caterin Rodriguez Verano 2025-12-11 12:25:22    94315912
# 293   Vivian Caterin Rodriguez Verano 2025-12-11 12:25:22  3163937546
# 294  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3117293523
# 295  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3168693335
# 296  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3105839709
#
#     Id deuda           Fecha act  \
# 0    1883138                 NaT
# 1    1931847                 NaT
# 2    1835885                 NaT
# 3    1908453                 NaT
# 4    1744144                 NaT
# ..       ...                 ...
# 292  1745159 2025-12-12 15:28:32
# 293  1950291                 NaT
# 294  1921130 2025-12-12 00:39:36
# 295  1831247 2025-12-15 17:39:01
# 296  2029933                 NaT
#
#                                           observations        que?
# 0                                                  NaN        <NA>
# 1                                                  NaN        <NA>
# 2                                                  NaN        <NA>
# 3                                                  NaN        <NA>
# 4                                                  NaN        <NA>
# ..                                                 ...         ...
# 292  10:27 a. m. 12/12/2025 VivianR// tt indica en ...   Esa deuda
# 293                                                NaN        <NA>
# 294                         Actualizado desde alianzas  Otra deuda
# 295   Vanessa Castillo/12: 38 pm//-15-12- 2025/ lle...  Otra deuda
# 296                                                NaN        <NA>
#
# [297 rows x 7 columns]

# %%
import numpy as np

df_seg = df_seg.copy()

df_seg["se gestionó"] = np.where(
    df_seg["Fecha act"].isna() & df_seg["observations"].isna(),
    "No",
    "Sí"
)

# %%
df_seg
# Out:
#                   Negociador asignado    Fecha asignación  Referencia  \
# 0           Alba Yohana Moreno Martin 2025-12-17 08:14:34  3188811171
# 1           Alba Yohana Moreno Martin 2025-12-17 08:14:34  3206158037
# 2           Alba Yohana Moreno Martin 2025-12-17 08:14:34    79249358
# 3                 Angela Yara Mayorga 2025-12-17 08:14:34    39463643
# 4                 Angela Yara Mayorga 2025-12-17 08:14:34  3054200634
# ..                                ...                 ...         ...
# 292   Vivian Caterin Rodriguez Verano 2025-12-11 12:25:22    94315912
# 293   Vivian Caterin Rodriguez Verano 2025-12-11 12:25:22  3163937546
# 294  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3117293523
# 295  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3168693335
# 296  Wendy Vanessa Castillo Velasquez 2025-12-11 12:25:22  3105839709
#
#     Id deuda           Fecha act  \
# 0    1883138                 NaT
# 1    1931847                 NaT
# 2    1835885                 NaT
# 3    1908453                 NaT
# 4    1744144                 NaT
# ..       ...                 ...
# 292  1745159 2025-12-12 15:28:32
# 293  1950291                 NaT
# 294  1921130 2025-12-12 00:39:36
# 295  1831247 2025-12-15 17:39:01
# 296  2029933                 NaT
#
#                                           observations        que? se gestionó
# 0                                                  NaN        <NA>          No
# 1                                                  NaN        <NA>          No
# 2                                                  NaN        <NA>          No
# 3                                                  NaN        <NA>          No
# 4                                                  NaN        <NA>          No
# ..                                                 ...         ...         ...
# 292  10:27 a. m. 12/12/2025 VivianR// tt indica en ...   Esa deuda          Sí
# 293                                                NaN        <NA>          No
# 294                         Actualizado desde alianzas  Otra deuda          Sí
# 295   Vanessa Castillo/12: 38 pm//-15-12- 2025/ lle...  Otra deuda          Sí
# 296                                                NaN        <NA>          No
#
# [297 rows x 8 columns]

# %%
import json
import pandas as pd
import gspread
from google.oauth2.service_account import Credentials
from gspread_dataframe import set_with_dataframe

# =========================================================
# 1. Cargar credenciales MI_JSON (Colab / GitHub)
# =========================================================
try:
    # Google Colab
    from google.colab import userdata
    mi_json = userdata.get("MI_JSON")
except ImportError:
    # GitHub / local
    import os
    mi_json = os.environ.get("MI_JSON")

if mi_json is None:
    raise ValueError("No se encontró MI_JSON en el entorno.")

creds_dict = json.loads(mi_json)

scopes = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive"
]

creds = Credentials.from_service_account_info(creds_dict, scopes=scopes)
gc = gspread.authorize(creds)

# =========================================================
# 2. Abrir el Google Sheet destino
# =========================================================
SPREADSHEET_ID = "1sMGQCCDiEzZI3f2w5BwFO8iWtxY5AEDJC2dypZ0NrCY"
SHEET_NAME = "Gestion"

sh = gc.open_by_key(SPREADSHEET_ID)

# =========================================================
# 3. Crear hoja "Gestion" (o limpiarla si ya existe)
# =========================================================
try:
    ws = sh.worksheet(SHEET_NAME)
    ws.clear()
except gspread.exceptions.WorksheetNotFound:
    ws = sh.add_worksheet(
        title=SHEET_NAME,
        rows=str(len(df_seg) + 5),
        cols=str(len(df_seg.columns) + 5)
    )

# =========================================================
# 4. Escribir df_seg en la hoja
# =========================================================
set_with_dataframe(
    ws,
    df_seg,
    include_index=False,
    include_column_header=True,
    resize=True
)

print("✅ df_seg escrito correctamente en la hoja 'Gestion'")
# Out:
# ✅ df_seg escrito correctamente en la hoja 'Gestion'
